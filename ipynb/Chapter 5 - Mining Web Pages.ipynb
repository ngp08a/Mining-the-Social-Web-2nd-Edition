# %% [raw]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 5: . Mining Web Pages: Using Natural Language Processing to Understand Human Language, Summarize Blog Posts, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# Note: If you find yourself wanting to copy output files from this notebook back to your host environment, see the bottom of this notebook for one possible way to do it.

# %% [markdown]
# ## Example 1. Using boilerpipe to extract the text from a web page

# %%
from boilerpipe.extract import Extractor

URL='http://radar.oreilly.com/2010/07/louvre-industrial-age-henry-ford.html'

extractor = Extractor(extractor='ArticleExtractor', url=URL)

print extractor.getText()
# Out:
# Listen
# The Louvre of the Industrial Age
# The Henry Ford is one of the world's great museums, and the world it chronicles is our own.
# by Tim O'Reilly | @timoreilly | +Tim O'Reilly | July 30, 2010
# This morning I had the chance to get a tour of The Henry Ford Museum in Dearborn, MI, along with Dale Dougherty, creator of Make: and Makerfaire, and Marc Greuther, the chief curator of the museum.  I had expected a museum dedicated to the auto industry, but it’s so much more than that.  As I wrote in my first stunned tweet, “it’s the Louvre of the Industrial Age.”
# When we first entered, Marc took us to what he said may be his favorite artifact in the museum, a block of concrete that contains Luther Burbank’s shovel, and Thomas Edison’s signature and footprints.  Luther Burbank was, of course, the great agricultural inventor who created such treasures as the nectarine and the Santa Rosa plum. Ford was a farm boy who became an industrialist; Thomas Edison was his friend and mentor. The museum, opened in 1929, was Ford’s personal homage to the transformation of the world that he was so much a part of.  This museum chronicles that transformation.
# The machines are astonishing – steam engines and coal-fired electric generators as big as houses, the first lathes capable of making other precision lathes (the makerbot of the 19th century), a ribbon glass machine that is one of five that in the 1970s made virtually all of the incandescent lightbulbs in the world, combine harvesters, railroad locomotives, cars, airplanes, even motels, gas stations, an early McDonalds’ restaurant and other epiphenomena of the automobile era.
# Under Marc’s eye, we also saw the transformation of the machines from purely functional objects to things of beauty.  We saw the advances in engineering — the materials, the workmanship, the design, over a hundred years of innovation.  Visiting The Henry Ford, as they call it, is a truly humbling experience.  I would never in a hundred years have thought of making a visit to Detroit just to visit this museum, but knowing what I know now, I will tell you confidently that it is as worth your while as a visit to Paris just to see the Louvre, to Rome for the Vatican Museum, to Florence for the Uffizi Gallery, to St. Petersburg for the Hermitage, or to Berlin for the Pergamon Museum.  This is truly one of the world’s great museums, and the world that it chronicles is our own.
# I am truly humbled that the Museum has partnered with us to hold Makerfaire Detroit on their grounds.  If you are anywhere in reach of Detroit this weekend, I heartily recommend that you plan to spend both days there.  You can easily spend a day at Makerfaire, and you could easily spend a day at The Henry Ford.
# P.S. Here are some of my photos from my visit .  (More to come soon. Can’t upload many as I’m currently on a plane.)
# Related:

# %% [markdown]
# ## Example 2. Using feedparser to extract the text (and other fields) from an RSS or Atom feed

# %%
import feedparser

FEED_URL='http://feeds.feedburner.com/oreilly/radar/atom'

fp = feedparser.parse(FEED_URL)

for e in fp.entries:
    print e.title
    print e.links[0].href
    print e.content[0].value
# Out:
# 6 best practices for giving a product critique
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/YK8gAhrQt1Y/6-best-practices-for-giving-a-product-critique.html
# <p><a href="https://www.flickr.com/photos/dannydansoy/14495142884"><img alt="Firewood_Stack_Support_Trusses_Dan_G_Flickr" class="aligncenter size-full wp-image-75831" height="240" src="http://s.radar.oreilly.com/wp-files/2/2015/04/Firewood_Stack_Support_Trusses_Dan_G_Flickr.jpg" width="620" /></a></p>
# <p style="margin-top: 20px; margin-bottom: 20px;"><em><strong><a href="http://www.oreilly.com/design/free/designing-for-the-internet-of-things.csp?intcmp=il-design-free-lp-lgen_20150416_designing_for_the_internet_of_things_excerpt_discussing_design_2nd_excerpt">Download a free copy of Designing for the Internet of Things</strong></a>, a curated collection of chapters from the O’Reilly Design library. <strong>This post is an excerpt</strong> from <a href="http://shop.oreilly.com/product/0636920033561.do?intcmp=il-design-books-videos-product-na_20150416_designing_for_the_internet_of_things_excerpt_discussing_design_2nd_excerpt">Discussing Design</a>, by <a href="https://twitter.com/adamconnor">Adam Connor</a> and <a href="https://twitter.com/aaroni">Aaron Irizarry</a>, one of the books included in the curated collection.</em></p>
# <p>There are two sides, or roles, in any critique:</p>
# <p><strong>Recipient:</strong> The individual(s) receiving the critique (i.e. the creator or presenter of whatever is being analyzed) who will take the perspectives and information raised during the critique, process it, and act upon it in some way.</p>
# <p><strong>Giver:</strong> The individual(s) giving the critique, who are being asked to think critically about the creation and provide their thoughts and perspectives.</p>
# <p>Within both of these roles, there is the discrete aspect of intention: why are we asking for/receiving/giving feedback. Intent is the initiator of the conversation and is often what separates successful critiques and feedback discussions from problematic ones.</p>
# <p>For the best discussions, the intent of each participant, regardless of whether they are receiving or giving critique, needs to be appropriate. If we aren’t careful, critique with the wrong, or inappropriate, intent on either side can lead to problems not only in our designs, but also in our ability to work with our teammates.<!--more--></p>
# <p>Receiving critique with the appropriate intent is about wanting to understand whether the decisions you’ve made are working toward your product’s (and its design’s) established objectives.</p>
# <p>[caption id="attachment_74387" align="alignright" width="237"]<a href="http://www.oreilly.com/design/free/designing-for-the-internet-of-things.csp?intcmp=il-design-free-lp-lgen_20150416_designing_for_the_internet_of_things_excerpt_discussing_design_2nd_excerpt_cover_image"><img alt="Designing for the Internet of Things - A curated collection of chapters from the O&#039;Reilly Design Library" class="size-full wp-image-74387" height="350" src="http://s.radar.oreilly.com/wp-files/2/2015/02/designing-for-the-iot-final-3.jpg" width="237" /></a> <em><a href="http://www.oreilly.com/design/free/designing-for-the-internet-of-things.csp?intcmp=il-design-free-lp-lgen_20150416_designing_for_the_internet_of_things_excerpt_discussing_design_2nd_excerpt_cover_image">Download the free ebook.</a></em>[/caption]Giving critique with the appropriate intent is about wanting to help the creator understand the impacts of their choices with regard to their effectiveness toward reaching the design’s objectives.</p>
# <p>Both acts are done with the intention of using the information and perspectives raised during the critique to iterate upon and strengthen the design. This is an important aspect of the discussion. Many of us have experienced meetings where we’re asked to give our thoughts on something like a design, or a process, or maybe even a project (ex: a postmortem), and over time, if these discussions repeatedly fail to produce action and changes, our desire to participate and provide our perspectives wanes.</p>
# <p>Part of what makes for strong critiques is the desire to participate, to help. It isn’t the case that everything said in a critique will produce a discrete modification to the design, but overall, participants should feel that the discussion, which they actively contributed to, played a role in improving the design, not just changing it, but strengthening its ability to produce the desired objectives.</p>
# <p>Prior to beginning a critique, whether you’re the giver or receiver, it’s best to make sure that you’re going in with the right intent.</p>
# <h2>Giving critique</h2>
# <p>As mentioned, giving critique with the right intent is about wanting to contribute to the improvement of the creation by helping the creator understand the relative success their design choices have in working toward objectives. When we start our feedback discussions from this mindset, we think critically not just about what we’re saying, but why we’re saying it, which is important to productive dialogues.</p>
# <p>To better understand what giving a good critique looks like, let’s first look at some characteristics of bad critique. For more tips on handling and working with unhelpful feedback and unwanted critique, see Chapter 5: Critiquing with Difficult People and Challenging Situations.</p>
# <h2>Characteristics of Bad Critique</h2>
# <p><strong>Selfish</strong></p>
# <p>The wrong intentions for giving critique are often selfish. They’re focused on personal goals and desires for attention at the expense of the team or other individuals, specifically the creator of whatever is being discussed.</p>
# <p>Selfish critique comes from the motivation of the giver to not only be heard and attract attention, but also to be recognized as smarter or superior, or further personal goals.</p>
# <p>The most recognizable examples of this can be seen on social networks like Twitter or Facebook whenever there is a change to a popular app, device, etc. A new feature is added or something is changed, and people immediately begin slamming decisions, calling them ridiculous and stupid, and stating how things “should have been designed.”</p>
# <p>But in most of these situations, the commenters have only a cursory understanding of what the designer or team was working toward and the constraints they were working within. How is this helpful?</p>
# <p>When we do this (and Aaron and I are guilty of it, too, as are most people) are we really trying to help someone improve their design? Or are we more interested in showing others in our community or organization how smart we are on a certain topic?</p>
# <p>This type of feedback happens on project teams as well. Maybe you’ve encountered it at work, are thinking of a colleague who’s done it to you, or maybe you’ve done it yourself.</p>
# <p>Sometimes, this kind of feedback comes from having our own ideas of what we think the design should be but not having had a chance to share it with the team. So, we set about to use feedback as a way to diminish the design being presented and (in some cases) propose our own alternative. While Aaron and I are firm believers that a great idea can come from anywhere, and team members in any role should be given an opportunity to share their ideas, this path to doing so is detrimental to a critique.</p>
# <p>As we’ll discuss more in Chapter 4, critique is not the place for exploring new ideas. Its purpose is to analyze the design as it has been created so far. Shifting a group from an analytical mindset to an explorative one is best done with deliberate facilitation.</p>
# <p><strong>Untimely</strong></p>
# <p>Despite what we may think, and what some people may even say, people aren’t always looking to hear feedback on their work. Unless someone has specifically told you they’d like your feedback, it’s unwise to think your conversation is a great opportunity to share your analysis with them. If someone is telling people about their creation, it may just be to get the word out or simply that they’re excited about what they’re working on.</p>
# <p>In order for the receiver to really listen, process, and make use of critique, they need to be in the proper mindset. Whether at a team member’s desk, in a meeting, or on social channels, when critique is uninvited, it can lead to defensiveness, communication breakdowns, and often paints the person giving it as a “know it all.”</p>
# <p><strong>Incomplete</strong></p>
# <p>For critique to be useful, the creator(s) need to understand not just the potential outcome or reaction to an element of their creation, but the <em>why</em> behind it. We often see feedback in the form of things like:</p>
# <blockquote><p>“I think the button is better than the link. Nobody is going to click on that.”</p></blockquote>
# <p>Or, even worse:</p>
# <blockquote><p>“This is terrible...”</p></blockquote>
# <p>This type of feedback typically comes from the reactive form of feedback we discussed in Chapter 1. It lacks the extended critical thinking that allows those working on the design to understand what they might need to change in their next iteration. In order for these critiques to become valuable, they need to be followed by an explanation as to <em>why</em> the giver is having that reaction or foresees a certain outcome. For example:</p>
# <blockquote><p>“Nobody is going to click on that because the current page design leads the eye down the left side of the screen, away from the call-to-action.”</p></blockquote>
# <p>Good critique is actionable. When the "why” behind the feedback is included, the comment can now be fully understood, and the creator can take action. That is to say, the creator has enough of an understanding of what is/isn’t working and why that they can explore alternatives or make other adjustments.</p>
# <p>Note, though, that this is different from prescription or direction. It is not the case that critique should tell the creator how to act on something or specifically what changes they should make (i.e. the directive form of feedback). Good critique tries to avoid problem solving, as it can detract and distract from the analytical focus of the discussion. For more on this, check out Chapter 4.</p>
# <p><strong>Preferential</strong></p>
# <p>Another common characteristic of bad critique is feedback that is justified by the giver from purely preferential thinking. We’ve all heard horror stories about this kind of feedback: designs are torn apart, not because a particular aspect isn’t working toward its objective, but rather it doesn’t match exactly what the feedback giver “likes.” For example: a website design gets canned because the color scheme reminds a stakeholder of a Christmas sweater his ex-wife had given him.</p>
# <p>Though it might seem ridiculous, this kind of feedback is common, though maybe not always so extreme. It usually feels like it’s coming out of nowhere and has no relevance to the work we’re doing, but sometimes, it really just boils down to a personal preference.</p>
# <p>This kind of feedback is not only unhelpful, as it does nothing to analyze a creation with regard to objectives, it can be distracting and counterproductive. This is especially the case when it comes from team members or stakeholders who are in a position of approval. In these situations, the team begins, consciously or subconsciously, to prioritize that individual’s tastes alongside or above project and user goals, even if they conflict.</p>
# <h2>Best practices for giving critique</h2>
# <p>Where critique with the wrong intent (done knowingly or not) is harmful, damaging teams, processes, and &mdash; most importantly &mdash; the product, useful, productive critique has the ability to strengthen relationships and collaboration, improve productivity, and lead to better designs. In order give the best critique possible, think about the following best practices when giving feedback.</p>
# <p><strong>Lead with questions. Get more information to base your feedback on and show an interest in their thinking.</strong></p>
# <p>Chances are, before being asked for your feedback, the creator(s) will give a brief explanation of what they’ve put together so far and how it would work. This gives you some context and understanding of the objectives they have and the elements of the design they’ve put in place to achieve them. But chances are, they haven’t explained everything. Actually, as we’ll talk about shortly, <em>hopefully</em> they haven’t explained everything.</p>
# <p>This is your chance to open up the dialogue. By asking questions, you give yourself more information on which to base your analysis and give stronger, actionable feedback. And if done in a non-interrogative way, it shows the creator that you’re genuinely interested in not only their work, but their thinking behind it, which can make discussing it and listening to feedback a bit easier for them.</p>
# <p>Examples of questions you might ask:</p>
# <ul>
# <li>Can you tell me more about what your objectives were for [specific aspect or element of the creation]?</li>
# <li>What other options did you consider for [aspect/element]?</li>
# <li>Why did you choose this approach for [aspect/element]?</li>
# <li>Were there any influencers or constraints that affected your choices?</li>
# </ul>
# <p>Remember though, the dual purpose of asking these questions of the creator:</p>
# <ol>
# <li>to get you more information and ...</li>
# <li>to get them more comfortable talking about their thought process and decisions.</li>
# </ol>
# <p>To that extent, how you ask these questions can have a huge impact. Asking every question beginning with “Why...” can feel abrasive or like an attack. Use lighter, more inviting phrasing such as, “tell me more about...”</p>
# <p><strong>Use a filter. Hold on to your initial reactions, investigate them and discuss them in the proper context as appropriate.</strong></p>
# <p>You’re going to have reactions. As the work is being presented to you, there will be things that make you think “huh?” or “that’s cool” or “I don’t get it” or maybe something worse. Hold onto those reactions and remember that reactions don’t typically make for useful feedback. Ask yourself why you’re reacting in that way. Ask the presenters additional questions if necessary.</p>
# <p>Once you understand your reaction and what caused it, think about whether it makes sense to discuss. Does it relate to the objectives of the product, the audience for it, or any particular best practices that should be followed? Or is it more about your personal preference or wishes for how you’d like to have seen it designed?</p>
# <p>If your feedback is related to the product’s objectives or best practices, and not about your personal reaction or preferences, then it definitely has a place in the conversation. Sometimes though, you may find yourself with feedback that, while not a best practice or preference, is also not specific to a best practice or a stated objective. Maybe it’s something new that you think should be considered. What should you do in those situations?</p>
# <p>In these cases, it may still be useful to bring your feedback into the conversation. These kinds of thoughts can be useful in determining additional objectives or constraints for the project that need to be exposed. It may be something you can discuss quickly and then continue on with the critique, or it may prove to be something sizeable that needs a separate, dedicated discussion so that the critique isn’t derailed.</p>
# <p><strong>Don’t assume. Find out the thinking or constraints behind choices.</strong></p>
# <p>“To assume makes an ass out of you and me.” Most of us have probably heard that line a few times in our lives. It’s one of my father’s favorites, and it’s stuck with me.</p>
# <p>Assumptions can be one of the worst things to happen in a discussion that is meant to be productive. When we make assumptions, we begin to form our thoughts, questions, and statements around them, without ever knowing if they’re true or not. And before you know it, the participants of the discussion go on their way to do their work based on very different ideas and producing work that doesn’t align with each other or reality.</p>
# <p>When you make assumptions in a critique about what an objective or constraint might have been, or maybe that there were no constraints and the designer could have done anything, you begin to offer feedback that can be less useful because it isn’t based on the real situation.</p>
# <p>To get around this is simple. The quickest way to eliminate assumptions is to ask about them.</p>
# <p>Yup. More questions. Put your assumption out there and ask if it’s accurate. If it is, continue on with your insights. If it isn’t, you may find that you need to adjust your thinking a little.</p>
# <p><strong>Don’t invite yourself. Get in touch and ask to talk about the design.</strong></p>
# <p>Recall in the previous section that we talked about untimely feedback as one of the types of unhelpful critique. If the recipient of the critique isn’t in a mindset where they want and are ready to listen to the feedback and use it, chances are it’ll be ignored or potentially cause a rift in your working relationship with them.</p>
# <p>If you have thoughts about someone’s creation and they haven’t explicitly asked for your feedback or critique, get in touch with them first and let them know. Tell them that, when they’re at a point when your thoughts might be helpful to them, you’d be happy to share them. Give them the opportunity to get themselves ready to listen.</p>
# <p><strong>Talk about strengths. Critique isn’t just about what’s not working.</strong></p>
# <p>As a culture and society, we have a tendency to focus on negatives, the things that cause us problems, get in our way, and that we’d like to see changed. We often take the positive for granted. In our project meeting and design discussions, it’s often no different &mdash; we spend the vast majority of time talking about what isn’t working. But that can be harmful. Remember that critique is about honest analysis. It’s balanced, focusing on the design and it’s objectives, regardless of their success. It’s just as important to talk about what is working and why, as it is what isn’t working.</p>
# <p>Often, when talking about the role of “positive feedback” in critique, we see discussions center on the importance of discussing strengths as a mechanism for making critical feedback easier for the receiver to take. There is a common structure often discussed called the “OREO” or “sandwich” method, in which you begin by offering a positive piece of feedback, followed by a negative one, followed by another positive one. It’s a fairly useful technique, which we’ll talk more about in Chapter 5, and there have been studies showing its effectiveness.</p>
# <p>But there are other reasons for making sure that critiques include discussion on what aspects of the design are working toward objectives and why/how.</p>
# <p>Part of the creative process involves the decomposition and abstraction of ideas and then recombining them in different ways or with ideas from somewhere else. It’s a common way in which we take a familiar concept where there is room for improvement or added value and innovate. When we talk about aspects of a product or design that are working, there is the potential for the creators to examine those areas and abstract concepts or elements from them that could be used to strengthen other areas of the design that might not be working as well.</p>
# <p>Additionally, with the understanding that the creator(s) will iterate upon their design after a critique, how much would it suck if at the next critique, you noticed that an aspect of the design that seemed great previously had now been changed and wasn’t quite as effective, all because it hadn’t been talked about, so the team didn’t see a reason not to change it.</p>
# <p><strong>Think about perspective. From whose “angle” are you analyzing the design?</strong></p>
# <p>In the previous section, we talked about preferential critique, or feedback that’s based on personal preferences rather than being tied to objectives for what we’re creating. When we’re analyzing a product, it can be easy to forget that we most likely aren’t representative of the product’s target audience. Even if we are a potential user, we know far more about it than the average user.</p>
# <p>As you analyze a design, it’s important for you to try to balance your expertise with the user’s perspective. It can be a difficult balance to strike, but by simply asking yourself “how am I looking at this” when you examine an aspect of the design and compare your perspective to what you think the user’s might be, you’ve got a good start. From there, you may find that one is clearly more appropriate than the other (i.e. your visceral hatred of the shade of green being used probably doesn’t matter), or perhaps it might be best to bring both up in the discussion. For example:</p>
# <blockquote><p>“From the user’s perspective, I think all of the steps in this flow make sense and are understandable and useable. But from an interaction design perspective, I think there may be some redundancy and opportunities to simplify..."</p></blockquote>
# <p><em>Cropped image on article and category pages by <a href="https://www.flickr.com/photos/dannydansoy/14495142884">Dan G on Flickr</a>, used under a <a href="https://creativecommons.org/licenses/by/2.0/">Creative Commons license</a>.</em></p>
# <div class="feedflare">
# <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=YK8gAhrQt1Y:axHklN9ue1M:V_sGLiPBpWU"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=YK8gAhrQt1Y:axHklN9ue1M:V_sGLiPBpWU" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=YK8gAhrQt1Y:axHklN9ue1M:yIl2AUoC8zA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=yIl2AUoC8zA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=YK8gAhrQt1Y:axHklN9ue1M:JEwB19i1-c4"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=YK8gAhrQt1Y:axHklN9ue1M:JEwB19i1-c4" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=YK8gAhrQt1Y:axHklN9ue1M:7Q72WNTAKBA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=7Q72WNTAKBA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=YK8gAhrQt1Y:axHklN9ue1M:qj6IDK7rITs"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=qj6IDK7rITs" /></a>
# </div><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/YK8gAhrQt1Y" width="1" />
# Four short links: 17 April 2015
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/EnsPmefcHaA/four-short-links-17-april-2015.html
# <ol>
# <li><a href="http://www.philipotoole.com/replicating-sqlite-using-raft-consensus/">Replicating SQLite using Raft Consensus</a> -- clever, he used a consensus algorithm to build a distributed (replicated) SQLite.</li>
# <li><a href="http://blogs.plos.org/scicomm/2015/04/13/hello-world/">When Open Access is the Norm, How do Scientists Communicate?</a> (PLOS) -- <i>From interviews I’ve conducted with researchers and software developers who are modeling aspects of modern online collaboration, I’ve highlighted the most useful and reproducible practices.</i> (via <a href="https://twitter.com/judell/status/587649580533071872">Jon Udell</a>)</li>
# <li><a href="https://www.yahoo.com/politics/meet-dj-patil-obamas-big-data-dude-deputy-chief-115849466441.html">Meet DJ Patil</a> -- <i>“It was this kind of moment when you realize: ‘Oh, my gosh, I am that stupid,’” he said.</i></li>
# <li><a href="http://www.nextnature.net/2015/02/interview-bruce-sterling-on-the-convergence-of-humans-and-machines/">Interview with Bruce Sterling on the Convergence of Humans and Machines</a> -- <i>If you are a human being, and you are doing computation, you are trying to multiply 17 times five in your head. It feels like thinking. Machines can multiply, too. They must be thinking. They can do math and you can do math. But the math you are doing is not really what cognition is about. Cognition is about stuff like seeing, maneuvering, having wants, desires. Your cat has cognition. Cats cannot multiply 17 times five. They have got their own umwelt (environment). But they are mammalian, you are a mammalian. They are actually a class that includes you. You are much more like your house cat than you are ever going to be like Siri. You and Siri converging, you and your house cat can converge a lot more easily. You can take the imaginary technologies that many post-human enthusiasts have talked about, and you could afflict all of them on a cat.  Every one of them would work on a cat. The cat is an ideal laboratory animal for all these transitions and convergences that we want to make for human beings.</i> (via <a href="https://twitter.com/vaughanbell/status/587982293014355968">Vaughan Bell</a>)</li>
# </ol>
# <div class="feedflare">
# <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=EnsPmefcHaA:d0X80O4Ijx4:V_sGLiPBpWU"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=EnsPmefcHaA:d0X80O4Ijx4:V_sGLiPBpWU" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=EnsPmefcHaA:d0X80O4Ijx4:yIl2AUoC8zA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=yIl2AUoC8zA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=EnsPmefcHaA:d0X80O4Ijx4:JEwB19i1-c4"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=EnsPmefcHaA:d0X80O4Ijx4:JEwB19i1-c4" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=EnsPmefcHaA:d0X80O4Ijx4:7Q72WNTAKBA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=7Q72WNTAKBA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=EnsPmefcHaA:d0X80O4Ijx4:qj6IDK7rITs"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=qj6IDK7rITs" /></a>
# </div><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/EnsPmefcHaA" width="1" />
# Experience design gives you the competitive edge
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/px8D3S19Pic/experience-design-gives-you-the-competitive-edge.html
# <p><img alt="spine_Marja_van_Bochove_Flickr" class="aligncenter size-full wp-image-75809" height="240" src="http://s.radar.oreilly.com/wp-files/2/2015/04/spine_Marja_van_Bochove_Flickr.jpg" width="620" /></p>
# <p style="margin-top: 20px; margin-bottom: 20px;"><em><strong><a href="https://itunes.apple.com/us/podcast/oreilly-radar/id491092046?intcmp=il-na-na-na-na_20150416_radar_text_subscribe_cta_andy_budd_radar_podcast">Subscribe to the O'Reilly Radar Podcast</a></strong> to track the technologies and people that will shape our world in the years to come.</em></p>
# <p>This week on the Radar Podcast, O'Reilly's <a href="https://twitter.com/marytreseler">Mary Treseler</a> chats with <a href="https://twitter.com/andybudd">Andy Budd</a>, a partner and UX designer at <a href="http://clearleft.com/">Clearleft</a>. Their wide-ranging conversation circles around lessons learned at Clearleft, understanding who your user really is, and why design agencies have a bright future. Budd also offers some insight into the people and projects he's keeping an eye on, or rather, as he explains, keeping a look out for &mdash; the next big things probably aren't yet on our radar, he says.</p>
# <p>As Clearleft, a user-experience design consultancy, has matured over its 10 or so years, Budd says they've gotten a lot more interested in the psychology and philosophy behind design, how designers' actions affect the world and society in general. The value of design, Budd notes, has been increasing over the past few years, becoming equal to &mdash; or even beginning to surpass &mdash; the prominence technology has traditionally enjoyed:</p>
# <blockquote><p>When I used to go to technology conferences, six, seven, eight years ago, the general narrative was around actual technology. It was around the developers as heroes around the technical stack being the main differentiator. Design was often lost in the conversation. Now, I think that's changed. I think in the last three or four years, actually the technology stack, and the technology in general, has become a lot more commoditized, with the rise of rapid prototyping tools, with the rises of libraries and frameworks, and also just the general maturation of products. I think it's very rare nowadays that a startup or product company will have, particularly in the Web space, will have a massive competitive advantage, just through technology alone. <!--more--></p>
# <p>...</p>
# <p>One of the reasons, I think, is that design is one of the few areas of the technology space, and the Web space, and the digital space that has a competitive advantage because it's really easy to copy an application technology when it launches, and create sort of a 'me-too' product. Actually, it's quite difficult to design a really, really good quality product and get the essence right. We see a lot of companies trying to mimic successful products, but they get them fundamentally wrong. Often, if you're just following on the trends, by the time you've copied somebody's application, another one will come out. The designers push out another new update and you find yourself, again, six months behind the curve. </p>
# <p>...</p>
# <p>I do think that, fundamentally, those companies that adopt a designful approach are much more likely to increase the delight that their products give, and, ultimately, increase the return of investment they get. Those companies that don't invest in design will find themselves struggling over the years to maintain their market position. </p></blockquote>
# <div style="width: 95%; border-top: 1px solid #ddd; border-bottom: 1px solid #ddd; padding: 10px; margin: 20px 0 20px 0; font-size: 110%;">
# <p style="text-align: center; margin-bottom: 5px;"><strong>Subscribe to the O'Reilly Radar Podcast</strong></p>
# <p style="text-align: center;"><a href="http://tunein.com/radio/OReilly-Radar-p663884/?intcmp=il-na-na-na-na_20150416_radar_tunein_embed_subscribe_cta_andy_budd_radar_podcast">TuneIn</a>, <a href="https://itunes.apple.com/us/podcast/oreilly-radar/id491092046?intcmp=il-na-na-na-na_20150416_radar_itunes_embed_subscribe_cta_andy_budd_radar_podcast">iTunes</a>, <a href="https://soundcloud.com/oreilly-radar/sets/oreilly-radar-podcast?intcmp=il-na-na-na-na_20150416_radar_soundcloud_embed_subscribe_cta_andy_budd_radar_podcast">SoundCloud</a>, <a href="http://feeds.feedburner.com/OreillyRadarPodcast?intcmp=il-na-na-na-na_20150416_radar_rss_embed_subscribe_cta_andy_budd_radar_podcast">RSS</a></p>
# <p>
# </div>
# <h2>Your customers aren't who you think they are</h2>
# <p>One of the design philosophies embraced at Clearleft traces back to a value list on the <a href="http://www.edenspiekermann.com/">Edenspiekermann</a> design agency website, Budd says: "You're not our customer; your clients are our customer." Budd notes that, though it may be painful, it's essential to have a firm grasp on who your end user really is:</p>
# <blockquote><p>Even though our clients are hiring us, we're designing, not for them and not necessarily for only their needs and their stakeholder needs, but we're really trying to see through that and design for their users. That can be painful because sometimes putting on that lens of the user needs can really highlight some fundamental failings within the structure or the approach or the outlook of our clients. ... Ultimately, what we're trying to do is we're trying to empathize with the user and trying to put the user's needs first. I truly believe that if you put the user's needs first, you can align those needs with the needs of the organization. It's much easier to align the organization's needs to the user's, then trying to somehow force the user's needs to the organization.</p></blockquote>
# <h2>Portents of promise?</h2>
# <p>In <a href="http://clearleft.com/thinks/thedeathoftheagencyhasbeengreatlyexaggerated/">a recent blog post</a>, Budd looked at the much-hyped "death of the agency" debate, declaring it "greatly exaggerated." In his conversation with Treseler, Budd says it's actually quite the opposite situation, that companies like <a href="http://www.adaptivepath.com/ideas/adaptive-path-where-were-going-next/">Capital One buying agencies like Adaptive Path</a> aren't the portents of doom they may seem:</p>
# <blockquote><p>The reason that Adaptive Path were bought out wasn't necessarily because they were struggling to find work. If anything, it was because Capital One valued them so much, and valued the design thinking so much, that they made them an offer that they couldn't refuse, to say we want all of this great talent to come in house. I don't think that's necessarily a failing of design, I think it's actually showing how important, how powerful design is.</p>
# <p>...</p>
# <p>I think that a lot of the stuff that's happening at the moment isn't something to be worried about, and isn't a warning sign on the wall that agencies are dead. I think what it is, is it's saying that agencies are so important now, are so valuable and design is so highly prized, that these agencies are having a much bigger impact on the world. I think that if design was failing, these agencies would be going out of business because there's no market. When in fact, I think what's happening is they're going out of business because the market is so valuable that they're being bought rather than disappearing because of poor cash flow. I think it's a positive sign.</p></blockquote>
# <h2>Designers on the brink</h2>
# <p>Five or six years ago, Budd says, he could have written out a list of the designers he found interesting or exciting, but things are different today; the difference, he explains, is that the industry has matured &mdash; where there were maybe 200 or even 2,000 designers doing incredible work seven or eight years ago, it's 20,000 today. Budd isn't keeping his eye on the limelight, he says &mdash; the next amazing designer probably isn't even on our radar yet:</p>
# <blockquote><p>The things I'm really interested in are the people I don't know about. There's all this amazing work going on that me and you and your listeners have never heard of. People who are doing great work in basements, in bedrooms, in co-working spaces around the world. They might not be well-known bloggers, they might not be well-known Twitter or Pinterest personalities, but they're amazing designers with amazing products. For me, that's the weird thing: The best people are the ones that have yet to publish their work, who are waiting on the precipice.</p>
# <p>It's kind of that whole thing about the future is here, it's just not evenly distributed. I think if you're focusing on particular individuals, they're already known by a certain number of people for a few years. It's the unknown people that excite me. ...That's the thing that excites me: the richness and maturity of our industry. There's not one or two leaders now, there's thousands of them.</p></blockquote>
# <div id="experience-design-cta">
# <div class="logo"><img alt="O'Reilly Experience Design for the Internet of Things Online Conference" src="http://cdn.oreillystatic.com/radar/images/promos/radar-experience-design-logo-20150410.svg" /></div>
# <h3>Design drives the future.</h3>
# <p>The online format brings this conference directly to you, as six leading designers share their knowledge, tools, techniques, and tips. Happening May 20, 2015.</p>
# <p><a class="cta" href="http://conferences.oreilly.com/experience-design-iot?intcmp=il-design-confreg-home-dsolc115_in_article_cta">View the program &gt;</a></div>
# <p><em>Cropped image by <a href="https://www.flickr.com/photos/on1stsite/4398178026">Marja van Bochove on Flickr</a>, used under a <a href="https://creativecommons.org/licenses/by/2.0/">Creative Commons license</a>.</em></p>
# <div class="feedflare">
# <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=px8D3S19Pic:CstCivWRQ5M:V_sGLiPBpWU"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=px8D3S19Pic:CstCivWRQ5M:V_sGLiPBpWU" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=px8D3S19Pic:CstCivWRQ5M:yIl2AUoC8zA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=yIl2AUoC8zA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=px8D3S19Pic:CstCivWRQ5M:JEwB19i1-c4"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=px8D3S19Pic:CstCivWRQ5M:JEwB19i1-c4" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=px8D3S19Pic:CstCivWRQ5M:7Q72WNTAKBA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=7Q72WNTAKBA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=px8D3S19Pic:CstCivWRQ5M:qj6IDK7rITs"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=qj6IDK7rITs" /></a>
# </div><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/px8D3S19Pic" width="1" />
# Four short links: 16 April 2015
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/qxQQ0W4eVW8/four-short-links-16-april-2015.html
# <ol>
# <li><a href="http://deepdive.stanford.edu/">DeepDive</a> -- <i>DeepDive is targeted to help users extract relations between entities from data and make inferences about facts involving the entities. DeepDive can process structured, unstructured, clean, or noisy data and outputs the results into a database.</i></li>
# <li><a href="http://arstechnica.com/the-multiverse/2015/04/from-the-vault-watching-and-re-watching-the-mother-of-all-demos/">From the Vault: Watching (and re-watching) “The Mother of All Demos”</a> -- <i>“I wish there was more about the social vision for computing—I worked with him for a long time, and Doug was always thinking ‘how can we collectively collaborate,’ like a sort of rock band.”</i></li>
# <li><a href="https://engineering.linkedin.com/kafka/running-kafka-scale">Running Kafka at Scale</a> (LinkedIn Engineering) -- <i>This tiered infrastructure solves many problems, but it greatly complicates monitoring Kafka and assuring its health. While a single Kafka cluster, when running normally, will not lose messages, the introduction of additional tiers, along with additional components such as mirror makers, creates myriad points of failure where messages can disappear. In addition to monitoring the Kafka clusters and their health, we needed to create a means to assure that all messages produced are present in each of the tiers, and make it to the critical consumers of that data.</i></li>
# <li><a href="http://pencerw.com/feed/2015/3/15/3d-printing-titanium-and-the-bin-of-broken-dreams">3D Printing Titanium, and the Bin of Broken Dreams</a> -- you will learn HUGE amounts on the challenges of real-world manufacturing by reading this.</li>
# </ol>
# <div class="feedflare">
# <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=qxQQ0W4eVW8:y5_plcyv5U0:V_sGLiPBpWU"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=qxQQ0W4eVW8:y5_plcyv5U0:V_sGLiPBpWU" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=qxQQ0W4eVW8:y5_plcyv5U0:yIl2AUoC8zA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=yIl2AUoC8zA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=qxQQ0W4eVW8:y5_plcyv5U0:JEwB19i1-c4"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=qxQQ0W4eVW8:y5_plcyv5U0:JEwB19i1-c4" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=qxQQ0W4eVW8:y5_plcyv5U0:7Q72WNTAKBA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=7Q72WNTAKBA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=qxQQ0W4eVW8:y5_plcyv5U0:qj6IDK7rITs"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=qj6IDK7rITs" /></a>
# </div><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/qxQQ0W4eVW8" width="1" />
# Zeta Architecture: Hexagon is the new circle
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/04WtyGht0Z4/zeta-architecture-hexagon-is-the-new-circle.html
# <p><a href="https://www.flickr.com/photos/11694215@N00/2430980955"><img alt="Eden_project_roof_Chris_Ford" class="aligncenter size-full wp-image-75741" height="240" src="http://s.radar.oreilly.com/wp-files/2/2015/04/Eden_project_roof_Chris_Ford.png" width="620" /></a></p>
# <p>Data processing in the enterprise goes very swiftly from "good enough" to "we need to be faster!" as expectations grow. The Zeta Architecture is an enterprise architecture that enables simplified business processes and defines a scalable way for increasing the speed of integrating data into the business. Following a bit of history and a description of the architecture, I'll use Google as an example and look at the way the company deploys technologies for Gmail.</p>
# <h2>Origin story and motivation</h2>
# <p>I’ve worked on a variety of different information systems over my career, each with their own classes of challenge. The most interesting from a capacity perspective was for a company that delivers digital advertising. The biggest technical problems in that industry flow from the sheer volume of transactions that occur on a daily basis. Traffic flows in all hours of the day, but there are certainly peak periods, which means all planning must revolve around the capacity during the peak hours. This solution space isn’t altogether different than that of Amazon; they had to build their infrastructure to handle massive loads of peak traffic. Both Amazon and digital advertising, incidentally, have a Black Friday spike.</p>
# <p>Many different architectural ideas came to my mind while I was in digital advertising. Real-time performance tracking of the advertising platform was one such thing. This was well before real-time became a hot buzzword in the technology industry. There was a point in time where this digital advertising company was “satisfied” with, or perhaps tolerated, having a two-to-three-hour delay between making changes to the system and having complete insight into the effects of the changes. After nearly a year at this company, I was finally able to get a large architectural change made to streamline log collection and management. Before the implementation started, I told everyone involved what would happen. Although this approach would enable the business to see the performance within approximately 5-10 minutes of the time a change was made, that this would not be good enough after people got a feel for what real-time could deliver. Since people didn’t have that taste in their mouths, they wouldn’t yet support going straight to real-time for this information. The implementation of this architecture was in place a few months after I departed the company for a new opportunity. The implementation worked great, and after about three months of experience with the new architecture, my former colleagues contacted me and told me they were looking to re-architect the entire solution to go to real time.<!--more--></p>
# <p>You might be wondering why I have decided to share this anecdote. It’s simple: “Good enough” doesn’t exist when it comes to technology. It is just a matter of time before people want more and faster. I predicted that my colleagues’ expectations would quickly change, and it proved to be true.</p>
# <p>All of those expectations got me thinking, “what could I do to protect against those new expectations that I knew were bound to happen?” Over the following few months, I worked through the ramifications to all the pieces of an enterprise architecture to help solve this. But there was still something missing. I couldn’t put my finger on it until I attended 2014 <a href="http://events.linuxfoundation.org/events/mesoscon">MesosCon</a> in Chicago. Finally, the last piece of my architecture was sitting in front of me. I was missing global resource management. When I added that in, it opened up new doors and new ways to benefit from the rest of the pieces of my architecture. Suddenly it hit me: the strategic combination of all of these pieces was greater than the sum of each of the parts.</p>
# <h2>High-level components with descriptions</h2>
# <p>The high-level component view of this architecture is intended to support the goals defined for this new architecture. It is not intended to dictate which specific software or project, open source or otherwise, that must be used. There are seven pluggable components of this new architecture, and all of the components must work together:</p>
# <ul>
# <li>Distributed file system &mdash; Utilizing a shared distributed file system, all applications will be able to read and write to a common location, which enables simplification of the rest of the architecture.</li>
# <li>Real-time data storage &mdash; This supports the need for high-speed business applications through the use of real-time databases.</li>
# <li>Pluggable compute model / execution engine &mdash; Different groups within a business have different needs and requirements for meeting the demands put upon them at any given time, which requires the support of potentially different engines and models to meet the needs of the business.</li>
# <li>Deployment / container management system &mdash; The need for having a standardized approach for deploying software are important and all resource consumers should be able to be isolated and deployed in a standard way.</li>
# <li>Solution architecture &mdash; This focuses on solving a particular business problem. There may be one or more applications built to deliver the complete solution. These solution architectures generally encompass a higher level interaction amongst common algorithms or libraries, software components, and business workflows. All too often, solution architectures are folded into enterprise architectures, but there is a clear separation with the Zeta Architecture.</li>
# <li>Enterprise applications &mdash; In the past, these applications would drive the rest of the architecture. However, in this new model, there is a shift. The rest of the architecture now simplifies these applications by delivering the components necessary to realize all of the business goals we are defining for this architecture.</li>
# <li>Dynamic and global resource management &mdash; Allows dynamic allocation of resources to enable the business to easily accommodate for whatever task is the most important today.</li>
# </ul>
# <p>After putting all of my ideas on paper, there were two things I still needed to do: design a visual representation to explain this architecture and, most importantly, name it. After finally coming up with a visual representation that was simple to understand, a name finally came to me. Thus was the Zeta Architecture begotten (I'll tell you the way I came up with the name in a future post).</p>
# <p>While thinking through the visuals and implementation details of this architecture, something else hit me. I stumbled upon a way to document Google’s architecture. I’ve never seen Google document what I will call their enterprise architecture, but this is it. This diagram maps out how Google operates its technology stack, with Gmail as a use case. This architecture will allow anyone who implements it to be able to run at Google scale and efficiency.</p>
# <p>[caption id="attachment_75730" align="aligncenter" width="570"]<img alt="Hexagon-Google_sized" class="size-full wp-image-75730" height="485" src="http://s.radar.oreilly.com/wp-files/2/2015/04/Hexagon-Google_sized.png" width="570" /> <em>Image courtesy of Jim Scott.</em>[/caption]</p>
# ...
# <p>Web development models include far more than code.  Creating great websites and applications demands collaboration among content creators, designers, and programmers.  As applications grow larger, supporting them requires adding a cast of people who can help them scale to demand.  As projects grow, specialization typically lets people focus on specific aspects of those larger disciplines, supporting networking, databases, template systems, graphics details, and much more.</p>
# <p>In some ways, that's a recipe for fragmentation, and some days the edges are sharp. All of these communities have different priorities, which conflict regularly.  Battles over resources sharpen the axes, and memories often linger.</p>
# <p>At the same time, though, often even in environments where resources are scarce, different perspectives can reinforce each other or create new possibilities. Sometimes, it's just because the intersection spaces have been left fallow for a long time, but other times, the combinations themselves create new opportunities.<!--more--></p>
# <p>I've <a href="http://radar.oreilly.com/2014/05/applying-design-values-to-programming.html">written before about the possibilities of applying design values in programming contexts</a>, but a concrete example keeps gaining traction lately: hypermedia.  It's an old term, going back to Ted Nelson's many efforts to mix computing into other disciplines, but it took off in the '90s to describe a wide variety of hypertext and multimedia projects, including the World Wide Web.  As the Web came to seem less exotic, the word faded.  Hypermedia has picked up a new charge, though, for computer-to-computer communications.  <a href="https://www.youtube.com/watch?v=W7NRMhZ4MDk">Many of the same ideas that work for human-to-human exchange and exploration work for computers</a>, and terms developed for human experience apply to APIs.</p>
# <p>Even though Web developers frequently enjoy contrasting their practical approaches with the "ivory tower" of academia, the Web is capable of absorbing lessons from doctoral dissertations.  Roy Fielding's 2000 UC Irvine dissertation, "<a href="https://www.ics.uci.edu/~fielding/pubs/dissertation/top.htm">Architectural Styles and<br />
# the Design of Network-based Software Architectures</a>" sounds pretty abstract, but the chapter on "Representational State Transfer (REST)" might sound familiar.  Of course, it probably also helps that Fielding co-founded the Apache HTTP Server project and was an active participant in various software and standards processes, but a lot of people found REST through that chapter.</p>
# <p>Some crossovers are made easier by similarities in roles.  I've enjoyed listening to <a href="http://radar.oreilly.com/2015/03/the-shape-of-software-architecture.html">software architects</a> and <a href="http://radar.oreilly.com/2014/10/experience-design-iot-design-business-design.html">experience designers</a> sharing war stories over a meal, finding that the challenges of human interaction while creating industrial-scale projects are, well, disturbingly similar.  Both roles require coordinating groups of people who have their own priorities, trying to get them to agree on core values and structures. The structures look very different on the surface, but there are often similarities.</p>
# <p><span class="pullquote-full">Creating great websites and applications demands collaboration among content creators, designers, and programmers.</span></p>
# <p>I always like to go to "Git for Designers" talks.  Git began as the epitome of a programmer's tool, initiated by Linus Torvalds over a weekend (a few months to completion) to manage the source code for Linux.  Pull requests?  Branches?  Diffs? Cryptographic history authentication?  Delta compression?  As it turns out, distributed development isn't just a programming problem.  Sympathetically told, git's story fits the needs of many kinds of Web developers.  <a href="http://github.com">GitHub</a> put git on the Web and added social features, and today you can even use <a href="http://www.smashingmagazine.com/2014/08/01/build-blog-jekyll-github-pages/">git to manage blog content</a>.</p>
# <p>As much as similarities can drive collaborations, though, differences and collisions can drive critical conversations.</p>
# <p>Accessibility is contentious.  Tearing down barriers often gets in the way of people who didn't realize they were building barriers as they built something they thought looked cool.  Accessibility folks rarely set out to be specialists in Web architecture, in the details of browsers, or in programmer education.  However, accessibility specialists have had to face and call out more bad and good practice than almost anyone else out there. They work with more tools and among more details than most developers, and while their work is primarily on the front end, it also requires an understanding of interaction with the back end. Many accessibility folks work as consultants, giving them an outsider status that makes it easier to acknowledge what's broken. If you need a good filter for what's best for the Web and its users, ask an accessibility specialist.</p>
# <p>Another key filter that often works through collision is the group of programmers who actually write the many browsers we all use.  In the early days of the Web, browsers were small, and there were many, but it still took a lot of programming effort to build one.  By the time Netscape released what became the open source code base of Mozilla in 1998, the Web was complicated and the skill sets were very different.  People asked whether enough Web people cared about C++ (or vice versa) to sustain such a project.  Today, it's clear there are enough people willing to see Web technologies from a programmer's eye to ensure that these projects can continue to flourish.  Some days the programmers wisely tell us that it's not yet time for processing-, memory-, or bandwidth-intensive features.</p>
# <p>Of course, these two groups and many others don't always agree, but that's much of why I'm glad the World Wide Web Consortium (<a href="http://w3.org/">W3C</a>) deliberately tries to include many different kinds of voices in its membership and experts.</p>
# <p>One last group, often unheralded, is key to the Web's cross-pollination: a constant flow of beginners.  For many people, the Web is their first stop in creating content, applications, and sites. They bring experience from everywhere.  That constant flow means that we have to take each other's crazy ideas a little more seriously than fields limited to experts.  In the long run, that openness &mdash; and especially that welcoming &mdash; is what keeps the Web diverse.</p>
# <p>Have your own stories about the success (or failure) of cross-pollination?  Let us know in the comments or through Twitter (<a href="http://twitter.com/simonstl">@simonstl</a>)!</p>
# <p><em>Photo by <a href="https://flic.kr/p/bwsBBK">Berit Watkin</a> on Flickr. Used under a <a href="https://creativecommons.org/licenses/by/2.0/">Creative Commons License</a>. This post is part of our ongoing exploration into <a href="http://radar.oreilly.com/tag/web-communities">cross-pollinating communities in the Web space</a>.</em></p>
# <div class="feedflare">
# <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=izWNb-MOK3w:cJlwBHgUBBc:V_sGLiPBpWU"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=izWNb-MOK3w:cJlwBHgUBBc:V_sGLiPBpWU" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=izWNb-MOK3w:cJlwBHgUBBc:yIl2AUoC8zA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=yIl2AUoC8zA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=izWNb-MOK3w:cJlwBHgUBBc:JEwB19i1-c4"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=izWNb-MOK3w:cJlwBHgUBBc:JEwB19i1-c4" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=izWNb-MOK3w:cJlwBHgUBBc:7Q72WNTAKBA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=7Q72WNTAKBA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=izWNb-MOK3w:cJlwBHgUBBc:qj6IDK7rITs"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=qj6IDK7rITs" /></a>
# </div><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/izWNb-MOK3w" width="1" />
# Open source won, so what&#8217;s next?
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/1xC5Uvy4meQ/open-source-won-so-whats-next.html
# <p><img alt="OSCON 2014 show floor" class="aligncenter size-full wp-image-75508" src="http://s.radar.oreilly.com/wp-files/2/2015/04/0415-oscon14-show-floor.jpg" width="620" /></p>
# <p>Twenty years ago, open source was a cause. Ten years ago, it was the underdog. Today, it sits upon the Iron Throne ruling all it surveys. Software engineers now use open source frameworks, languages, and tools in almost all projects. </p>
# <p>When I was putting together the program for <a href="http://www.oscon.com/open-source-2015?intcmp=il-prog-confreg-update-os15_20150409_radar_oscon_15_announcement">OSCON</a> with the other <a href="http://www.oscon.com/open-source-2015/public/content/about#chairs">program chairs</a>, it occurred to me that by covering "just" open source, we weren't really leaving out all that much of the software landscape. It seems open source has indeed won, but let's not gloat; let's make things even better. Open source has made many great changes to software possible, but the spirit of the founding community goes well beyond code.<!--more--></p>
# <h2>Pieces of a larger puzzle: Languages, libraries, and frameworks</h2>
# <p>Open source languages such as Java, Python, and Ruby benefit from communities that not only report problems, but add to the efficacy and optimization of a language. New libraries and frameworks augment these and other open source languages by giving software engineers tools to solve problems quickly. However, languages with their libraries and frameworks are but the tools to get things done. </p>
# <p>In the past, we've organized OSCON's tracks by language. This reflected a time when software engineers tended to stick to one language or another. This was before the days of 782 JavaScript frameworks and several different languages, database choices, and architectures that are optimized for different types of projects. Well, no more! </p>
# <p>This year, you'll see that we've set the tracks so they reflect what you, the software engineer, need to get things done.</p>
# <ul>
# <li> <strong>Protect</strong> &mdash; Identity, privacy, and security are emerging and nuanced facets in the digital age, and now they're also an exciting cross-functional track at OSCON 2015.</li>
# <li> <strong>Scale</strong> &mdash; From compilation and interpreter time to DOM manipulation, browser responsiveness, and network latency, we'll explore scale and performance in all their aspects.</li>
# <li> <strong>Mobility</strong> &mdash; We'll look at what it means to have a successful mobile game plan, from wearables to native apps.</li>
# <li> <strong>Collaboration</strong> &mdash; Making projects work requires communication, collaboration, and respect. We'll look at the ways a new generation of tools and approaches can help you work.</li>
# <li> <strong>Craft</strong> &mdash; You need to work on you! We'll present ideas on how to fail fast, say “no,” overcome impostor syndrome, and integrate your work into the open source community.</li>
# <li> <strong>Architecture</strong> &mdash; Software architecture is a massive multidisciplinary subject, covering many roles and responsibilities &mdash; and it's a key position in the success of any business.</li>
# <li> <strong>Design</strong> &mdash; It's critical for success; learn how to incorporate design best practices from the beginning of your project and all the way through.</li>
# <li> <strong>Data</strong> &mdash; We'll tackle data's continued, growing influence over the entire business world and present ways you can make it work for you.</li>
# <li> <strong>Foundations</strong> &mdash; A strong foundation in computational thinking, problem solving, and programming best practices makes for a successful programmer.</li>
# <li> <strong>Solve</strong> &mdash; Harness the power of math to manipulate, secure, and create data.</li>
# </ul>
# <p>Over the next few weeks, look for posts that go into more depth about each of these tracks.</p>
# <h2>An evolved software community</h2>
# <p>As I mentioned in my recent post "<a href="http://radar.oreilly.com/2015/02/software-engineer-developer-coding-architecture-mobile-open-source.html">Software engineers must continuously learn and integrate</a>," organizations need to integrate open source code and open source culture if they want to move at a speed that will drive success. This year, <a href="http://www.oscon.com/open-source-2015/public/schedule/topic/1405?intcmp=il-prog-confreg-update-os15_20150409_radar_oscon_15_announcement_cultivate">we'll focus on company culture via Cultivate</a>, a two-day event at OSCON. We'll discuss the values and practices that enable organizations to respond with agility to changes in their products and their customers. If you need to learn about growing teams within your organization, instilling leadership skills that are necessary for success now and in the future, and creating processes that work for rather than against you, you need to be at <a href="http://www.oscon.com/open-source-2015/public/schedule/topic/1405?intcmp=il-prog-confreg-update-os15_20150409_radar_oscon_15_announcement_cultivate">Cultivate</a>. </p>
# <h2>OSCON, reimagined</h2>
# <p>OSCON touches upon all aspects of the software industry and what we cover at O'Reilly. It's been at the heart of what we do for almost 18 years. But going forward, we want to make sure we continue to meet the needs of our community while advancing the open source message. That's why we're taking a new approach with the event's structure. </p>
# <p>Whether you're attending OSCON for the first time or you've been to this conference many times before, you're already a part of this thriving community. We look forward to showing you what we have in store as OSCON is expanded and reimagined.</p>
# <p style="margin-top: 25px; margin-bottom: 40px;"><a href="http://www.oscon.com/open-source-2015?intcmp=il-prog-confreg-update-os15_20150409_radar_oscon_15_announcement"><strong>Learn more about the OSCON 2015 program</strong></a>.</p>
# <div class="feedflare">
# <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=1xC5Uvy4meQ:1m11tPQSMnk:V_sGLiPBpWU"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=1xC5Uvy4meQ:1m11tPQSMnk:V_sGLiPBpWU" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=1xC5Uvy4meQ:1m11tPQSMnk:yIl2AUoC8zA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=yIl2AUoC8zA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=1xC5Uvy4meQ:1m11tPQSMnk:JEwB19i1-c4"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?i=1xC5Uvy4meQ:1m11tPQSMnk:JEwB19i1-c4" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=1xC5Uvy4meQ:1m11tPQSMnk:7Q72WNTAKBA"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=7Q72WNTAKBA" /></a> <a href="http://feeds.feedburner.com/~ff/oreilly/radar/atom?a=1xC5Uvy4meQ:1m11tPQSMnk:qj6IDK7rITs"><img border="0" src="http://feeds.feedburner.com/~ff/oreilly/radar/atom?d=qj6IDK7rITs" /></a>
# </div><img alt="" height="1" src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/1xC5Uvy4meQ" width="1" />

# %% [markdown]
# ## Example 3. Pseudocode for a breadth-first search

# %%
Create an empty graph
Create an empty queue to keep track of nodes that need to be processed

Add the starting point to the graph as the root node
Add the root node to a queue for processing

Repeat until some maximum depth is reached or the queue is empty:
  Remove a node from the queue 
  For each of the node's neighbors: 
    If the neighbor hasn't already been processed: 
      Add it to the queue 
      Add it to the graph 
      Create an edge in the graph that connects the node and its neighbor
# Out:
#   File "<ipython-input-6-f4a13a9af5cd>", line 1
#     Create an empty graph
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Naive sentence detection based on periods**

# %%
txt = "Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow."
print txt.split(".")
# Out:
# ['Mr', ' Green killed Colonel Mustard in the study with the candlestick', ' Mr', ' Green is not a very nice fellow', '']

# %% [markdown]
# **More sophisticated sentence detection**

# %%
import nltk

# Downloading nltk packages used in this example
nltk.download('punkt')

sentences = nltk.tokenize.sent_tokenize(txt)
print sentences
# Out:
# [nltk_data] Downloading package 'punkt' to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['Mr. Green killed Colonel Mustard in the study with the candlestick.', 'Mr. Green is not a very nice fellow.']

# %% [markdown]
# **Tokenization of sentences**

# %%
tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
print tokens
# Out:
# [['Mr.', 'Green', 'killed', 'Colonel', 'Mustard', 'in', 'the', 'study', 'with', 'the', 'candlestick', '.'], ['Mr.', 'Green', 'is', 'not', 'a', 'very', 'nice', 'fellow', '.']]

# %% [markdown]
# **Part of speech tagging for tokens**

# %%
# Downloading nltk packages used in this example
nltk.download('maxent_treebank_pos_tagger')

pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]
print pos_tagged_tokens
# Out:
# [nltk_data] Downloading package 'maxent_treebank_pos_tagger' to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_treebank_pos_tagger is already up-to-
# [nltk_data]       date!
# [[('Mr.', 'NNP'), ('Green', 'NNP'), ('killed', 'VBD'), ('Colonel', 'NNP'), ('Mustard', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('study', 'NN'), ('with', 'IN'), ('the', 'DT'), ('candlestick', 'NN'), ('.', '.')], [('Mr.', 'NNP'), ('Green', 'NNP'), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('very', 'RB'), ('nice', 'JJ'), ('fellow', 'JJ'), ('.', '.')]]

# %% [markdown]
# **Named entity extraction/chunking for tokens**

# %%
# Downloading nltk packages used in this example
nltk.download('maxent_ne_chunker')
nltk.download('words')

ne_chunks = nltk.batch_ne_chunk(pos_tagged_tokens)
print ne_chunks
print ne_chunks[0].pprint() # You can prettyprint each chunk in the tree
# Out:
# [nltk_data] Downloading package 'maxent_ne_chunker' to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package 'words' to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [Tree('S', [Tree('PERSON', [('Mr.', 'NNP')]), Tree('PERSON', [('Green', 'NNP')]), ('killed', 'VBD'), Tree('ORGANIZATION', [('Colonel', 'NNP'), ('Mustard', 'NNP')]), ('in', 'IN'), ('the', 'DT'), ('study', 'NN'), ('with', 'IN'), ('the', 'DT'), ('candlestick', 'NN'), ('.', '.')]), Tree('S', [Tree('PERSON', [('Mr.', 'NNP')]), Tree('ORGANIZATION', [('Green', 'NNP')]), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('very', 'RB'), ('nice', 'JJ'), ('fellow', 'JJ'), ('.', '.')])]
# (S
#   (PERSON Mr./NNP)
#   (PERSON Green/NNP)
#   killed/VBD
#   (ORGANIZATION Colonel/NNP Mustard/NNP)
#   in/IN
#   the/DT
#   study/NN
#   with/IN
#   the/DT
#   candlestick/NN
#   ./.)

# %% [markdown]
# ## Example 4. Harvesting blog data by parsing feeds

# %%
import os
import sys
import json
import feedparser
from BeautifulSoup import BeautifulStoneSoup
from nltk import clean_html

FEED_URL = 'http://feeds.feedburner.com/oreilly/radar/atom'

def cleanHtml(html):
    return BeautifulStoneSoup(clean_html(html), convertEntities=BeautifulStoneSoup.HTML_ENTITIES).contents[0]
                              
fp = feedparser.parse(FEED_URL)
                              
print "Fetched %s entries from '%s'" % (len(fp.entries[0].title), fp.feed.title)

blog_posts = []
for e in fp.entries:
    blog_posts.append({'title': e.title, 'content': cleanHtml(e.content[0].value), 'link': e.links[0].href})
    
out_file = os.path.join('resources', 'ch05-webpages', 'feed.json')
f = open(out_file, 'w')
f.write(json.dumps(blog_posts, indent=1))
f.close()

print 'Wrote output file to %s' % (f.name, )
# Out:
# Fetched 46 entries from 'O'Reilly Radar - Insight, analysis, and research about emerging technologies'
# Wrote output file to resources/ch05-webpages/feed.json

# %% [markdown]
# ## Example 5. Using NLTK’s NLP tools to process human language in blog data

# %%
import json
import nltk

# Download nltk packages used in this example
nltk.download('stopwords')

BLOG_DATA = "resources/ch05-webpages/feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

# Customize your list of stopwords as needed. Here, we add common
# punctuation and contraction artifacts.

stop_words = nltk.corpus.stopwords.words('english') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    u'—',
    ]

for post in blog_data:
    sentences = nltk.tokenize.sent_tokenize(post['content'])

    words = [w.lower() for sentence in sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    # Basic stats

    num_words = sum([i[1] for i in fdist.items()])
    num_unique_words = len(fdist.keys())

    # Hapaxes are words that appear only once

    num_hapaxes = len(fdist.hapaxes())

    top_10_words_sans_stop_words = [w for w in fdist.items() if w[0]
                                    not in stop_words][:10]

    print post['title']
    print '\tNum Sentences:'.ljust(25), len(sentences)
    print '\tNum Words:'.ljust(25), num_words
    print '\tNum Unique Words:'.ljust(25), num_unique_words
    print '\tNum Hapaxes:'.ljust(25), num_hapaxes
    print '\tTop 10 Most Frequent Words (sans stop words):\n\t\t', \
            '\n\t\t'.join(['%s (%s)'
            % (w[0], w[1]) for w in top_10_words_sans_stop_words])
    print
# Out:
# [nltk_data] Downloading package 'stopwords' to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 6 best practices for giving a product critique
# 	Num Sentences:           147
# 	Num Words:               3527
# 	Num Unique Words:        864
# 	Num Hapaxes:             489
# 	Top 10 Most Frequent Words (sans stop words):
# 		critique (44)
# 		feedback (35)
# 		design (27)
# 		working (17)
# 		it’s (14)
# 		think (14)
# 		objectives (13)
# 		creator (12)
# 		best (11)
# 		get (10)
#
# Four short links: 17 April 2015
# 	Num Sentences:           22
# 	Num Words:               328
# 	Num Unique Words:        171
# 	Num Hapaxes:             121
# 	Top 10 Most Frequent Words (sans stop words):
# 		cat (6)
# 		like (4)
# 		cognition (3)
# 		math (3)
# 		multiply (3)
# 		17 (2)
# 		consensus (2)
# 		five (2)
# 		house (2)
# 		human (2)
#
# Experience design gives you the competitive edge
# 	Num Sentences:           52
# 	Num Words:               1443
# 	Num Unique Words:        463
# 	Num Hapaxes:             282
# 	Top 10 Most Frequent Words (sans stop words):
# 		design (17)
# 		think (14)
# 		n't (12)
# 		budd (10)
# 		needs (9)
# 		years (9)
# 		really (8)
# 		technology (8)
# 		user (8)
# 		designers (7)
#
# Four short links: 16 April 2015
# 	Num Sentences:           6
# 	Num Words:               230
# 	Num Unique Words:        146
# 	Num Hapaxes:             112
# 	Top 10 Most Frequent Words (sans stop words):
# 		kafka (4)
# 		data (3)
# 		deepdive (3)
# 		messages (3)
# 		additional (2)
# 		entities (2)
# 		health (2)
# 		make (2)
# 		monitoring (2)
# 		running (2)
#
# Zeta Architecture: Hexagon is the new circle
# 	Num Sentences:           92
# 	Num Words:               1921
# 	Num Unique Words:        652
# 	Num Hapaxes:             393
# 	Top 10 Most Frequent Words (sans stop words):
# 		architecture (29)
# 		'' (25)
# 		business (13)
# 		solution (9)
# 		[ (8)
# 		] (8)
# 		data (8)
# 		google (8)
# 		new (8)
# 		zeta (8)
#
# Four short links: 15 April 2015
# 	Num Sentences:           13
# 	Num Words:               365
# 	Num Unique Words:        223
# 	Num Hapaxes:             171
# 	Top 10 Most Frequent Words (sans stop words):
# 		clustering (3)
# 		data (3)
# 		facebook (3)
# 		it’s (3)
# 		series (3)
# 		time (3)
# 		certain (2)
# 		claim (2)
# 		clusters (2)
# 		constraint (2)
#
# Rebooting a 1970s satellite with modern software and hardware
# 	Num Sentences:           18
# 	Num Words:               534
# 	Num Unique Words:        266
# 	Num Hapaxes:             197
# 	Top 10 Most Frequent Words (sans stop words):
# 		solid (9)
# 		'' (6)
# 		dennis (6)
# 		satellite (6)
# 		`` (4)
# 		hardware (4)
# 		podcast (4)
# 		wingo (4)
# 		analog (3)
# 		nasa (3)
#
# Beyond bitcoin and the blockchain to booming business
# 	Num Sentences:           46
# 	Num Words:               1285
# 	Num Unique Words:        577
# 	Num Hapaxes:             427
# 	Top 10 Most Frequent Words (sans stop words):
# 		financial (13)
# 		currency (10)
# 		blockchain (9)
# 		digital (9)
# 		new (7)
# 		industry (6)
# 		services (6)
# 		bitcoin (5)
# 		companies (5)
# 		bank (4)
#
# Four short links: 14 April 2015
# 	Num Sentences:           7
# 	Num Words:               187
# 	Num Unique Words:        120
# 	Num Hapaxes:             85
# 	Top 10 Most Frequent Words (sans stop words):
# 		test (4)
# 		a/a (3)
# 		also (2)
# 		computing (2)
# 		documentary (2)
# 		father (2)
# 		much (2)
# 		nsa (2)
# 		pycon (2)
# 		run (2)
#
# Four short links: 13 April 2015
# 	Num Sentences:           12
# 	Num Words:               282
# 	Num Unique Words:        173
# 	Num Hapaxes:             133
# 	Top 10 Most Frequent Words (sans stop words):
# 		change (3)
# 		cognitive (3)
# 		cultural (2)
# 		demand (2)
# 		descriptions (2)
# 		educated (2)
# 		employment (2)
# 		impossible (2)
# 		model (2)
# 		models (2)
#
# 5 reasons why Python is a popular teaching language
# 	Num Sentences:           150
# 	Num Words:               3767
# 	Num Unique Words:        1023
# 	Num Hapaxes:             606
# 	Top 10 Most Frequent Words (sans stop words):
# 		python (46)
# 		code (31)
# 		'' (28)
# 		[ (25)
# 		] (25)
# 		> (21)
# 		language (20)
# 		list (14)
# 		use (14)
# 		! (12)
#
# In design, what we really need is critical thinking
# 	Num Sentences:           89
# 	Num Words:               2146
# 	Num Unique Words:        627
# 	Num Hapaxes:             370
# 	Top 10 Most Frequent Words (sans stop words):
# 		feedback (36)
# 		design (18)
# 		it’s (14)
# 		reaction (13)
# 		us (12)
# 		might (9)
# 		something (9)
# 		created (7)
# 		creation (7)
# 		form (7)
#
# Four short links: 10 April 2015
# 	Num Sentences:           14
# 	Num Words:               351
# 	Num Unique Words:        199
# 	Num Hapaxes:             152
# 	Top 10 Most Frequent Words (sans stop words):
# 		data (14)
# 		quality (4)
# 		computer (3)
# 		problem (3)
# 		team (3)
# 		touch (3)
# 		tracking (3)
# 		... (2)
# 		[ (2)
# 		] (2)
#
# Cross-pollinating Web communities
# 	Num Sentences:           63
# 	Num Words:               1243
# 	Num Unique Words:        534
# 	Num Hapaxes:             369
# 	Top 10 Most Frequent Words (sans stop words):
# 		web (22)
# 		many (11)
# 		people (9)
# 		often (6)
# 		projects (6)
# 		work (6)
# 		`` (5)
# 		accessibility (5)
# 		designers (5)
# 		different (5)
#
# Open source won, so what&#8217;s next?
# 	Num Sentences:           39
# 	Num Words:               858
# 	Num Unique Words:        353
# 	Num Hapaxes:             235
# 	Top 10 Most Frequent Words (sans stop words):
# 		open (11)
# 		source (11)
# 		software (10)
# 		oscon (9)
# 		'll (8)
# 		languages (6)
# 		work (6)
# 		community (5)
# 		frameworks (5)
# 		need (5)

# %% [markdown]
# ## Example 6. A document summarization algorithm based principally upon sentence detection and frequency analysis within sentences

# %%
import json
import nltk
import numpy

BLOG_DATA = "resources/ch05-webpages/feed.json"

N = 100  # Number of words to consider
CLUSTER_THRESHOLD = 5  # Distance between words to consider
TOP_SENTENCES = 5  # Number of sentences to return for a "top n" summary

# Approach taken from "The Automatic Creation of Literature Abstracts" by H.P. Luhn

def _score_sentences(sentences, important_words):
    scores = []
    sentence_idx = -1

    for s in [nltk.tokenize.word_tokenize(s) for s in sentences]:

        sentence_idx += 1
        word_idx = []

        # For each word in the word list...
        for w in important_words:
            try:
                # Compute an index for where any important words occur in the sentence.

                word_idx.append(s.index(w))
            except ValueError, e: # w not in this particular sentence
                pass

        word_idx.sort()

        # It is possible that some sentences may not contain any important words at all.
        if len(word_idx)== 0: continue

        # Using the word index, compute clusters by using a max distance threshold
        # for any two consecutive words.

        clusters = []
        cluster = [word_idx[0]]
        i = 1
        while i < len(word_idx):
            if word_idx[i] - word_idx[i - 1] < CLUSTER_THRESHOLD:
                cluster.append(word_idx[i])
            else:
                clusters.append(cluster[:])
                cluster = [word_idx[i]]
            i += 1
        clusters.append(cluster)

        # Score each cluster. The max score for any given cluster is the score 
        # for the sentence.

        max_cluster_score = 0
        for c in clusters:
            significant_words_in_cluster = len(c)
            total_words_in_cluster = c[-1] - c[0] + 1
            score = 1.0 * significant_words_in_cluster \
                * significant_words_in_cluster / total_words_in_cluster

            if score > max_cluster_score:
                max_cluster_score = score

        scores.append((sentence_idx, score))

    return scores

def summarize(txt):
    sentences = [s for s in nltk.tokenize.sent_tokenize(txt)]
    normalized_sentences = [s.lower() for s in sentences]

    words = [w.lower() for sentence in normalized_sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    top_n_words = [w[0] for w in fdist.items() 
            if w[0] not in nltk.corpus.stopwords.words('english')][:N]

    scored_sentences = _score_sentences(normalized_sentences, top_n_words)

    # Summarization Approach 1:
    # Filter out nonsignificant sentences by using the average score plus a
    # fraction of the std dev as a filter

    avg = numpy.mean([s[1] for s in scored_sentences])
    std = numpy.std([s[1] for s in scored_sentences])
    mean_scored = [(sent_idx, score) for (sent_idx, score) in scored_sentences
                   if score > avg + 0.5 * std]

    # Summarization Approach 2:
    # Another approach would be to return only the top N ranked sentences

    top_n_scored = sorted(scored_sentences, key=lambda s: s[1])[-TOP_SENTENCES:]
    top_n_scored = sorted(top_n_scored, key=lambda s: s[0])

    # Decorate the post object with summaries

    return dict(top_n_summary=[sentences[idx] for (idx, score) in top_n_scored],
                mean_scored_summary=[sentences[idx] for (idx, score) in mean_scored])

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:
       
    post.update(summarize(post['content']))

    print post['title']
    print '=' * len(post['title'])
    print
    print 'Top N Summary'
    print '-------------'
    print ' '.join(post['top_n_summary'])
    print
    print 'Mean Scored Summary'
    print '-------------------'
    print ' '.join(post['mean_scored_summary'])
    print
# Out:
# 6 best practices for giving a product critique
# ==============================================
#
# Top N Summary
# -------------
# Giver: The individual(s) giving the critique, who are being asked to think critically about the creation and provide their thoughts and perspectives. Giving critique
#  As mentioned, giving critique with the right intent is about wanting to contribute to the improvement of the creation by helping the creator understand the relative success their design choices have in working toward objectives. For more tips on handling and working with unhelpful feedback and unwanted critique, see Chapter 5: Critiquing with Difficult People and Challenging Situations. Hold onto those reactions and remember that reactions don’t typically make for useful feedback. Find out the thinking or constraints behind choices.
#
# Mean Scored Summary
# -------------------
# Giver: The individual(s) giving the critique, who are being asked to think critically about the creation and provide their thoughts and perspectives. Within both of these roles, there is the discrete aspect of intention: why are we asking for/receiving/giving feedback. Intent is the initiator of the conversation and is often what separates successful critiques and feedback discussions from problematic ones. Receiving critique with the appropriate intent is about wanting to understand whether the decisions you’ve made are working toward your product’s (and its design’s) established objectives. This is an important aspect of the discussion. Giving critique
#  As mentioned, giving critique with the right intent is about wanting to contribute to the improvement of the creation by helping the creator understand the relative success their design choices have in working toward objectives. For more tips on handling and working with unhelpful feedback and unwanted critique, see Chapter 5: Critiquing with Difficult People and Challenging Situations. Shifting a group from an analytical mindset to an explorative one is best done with deliberate facilitation. It is not the case that critique should tell the creator how to act on something or specifically what changes they should make (i.e. the directive form of feedback). In order give the best critique possible, think about the following best practices when giving feedback. Lead with questions. Examples of questions you might ask:
#
#  Can you tell me more about what your objectives were for [specific aspect or element of the creation]? What other options did you consider for [aspect/element]? Why did you choose this approach for [aspect/element]? You’re going to have reactions. As the work is being presented to you, there will be things that make you think “huh?” or “that’s cool” or “I don’t get it” or maybe something worse. Hold onto those reactions and remember that reactions don’t typically make for useful feedback. Does it relate to the objectives of the product, the audience for it, or any particular best practices that should be followed? Maybe it’s something new that you think should be considered. In these cases, it may still be useful to bring your feedback into the conversation. These kinds of thoughts can be useful in determining additional objectives or constraints for the project that need to be exposed. Find out the thinking or constraints behind choices. If it isn’t, you may find that you need to adjust your thinking a little. Get in touch and ask to talk about the design. In our project meeting and design discussions, it’s often no different — we spend the vast majority of time talking about what isn’t working. But there are other reasons for making sure that critiques include discussion on what aspects of the design are working toward objectives and why/how. Think about perspective. From there, you may find that one is clearly more appropriate than the other (i.e.
#
# Four short links: 17 April 2015
# ===============================
#
# Top N Summary
# -------------
# Replicating SQLite using Raft Consensus -- clever, he used a consensus algorithm to build a distributed (replicated) SQLite. When Open Access is the Norm, How do Scientists Communicate? Interview with Bruce Sterling on the Convergence of Humans and Machines -- If you are a human being, and you are doing computation, you are trying to multiply 17 times five in your head. Cats cannot multiply 17 times five. You and Siri converging, you and your house cat can converge a lot more easily.
#
# Mean Scored Summary
# -------------------
# Replicating SQLite using Raft Consensus -- clever, he used a consensus algorithm to build a distributed (replicated) SQLite. When Open Access is the Norm, How do Scientists Communicate? Interview with Bruce Sterling on the Convergence of Humans and Machines -- If you are a human being, and you are doing computation, you are trying to multiply 17 times five in your head. It feels like thinking. Cats cannot multiply 17 times five. You are much more like your house cat than you are ever going to be like Siri. You and Siri converging, you and your house cat can converge a lot more easily.
#
# Experience design gives you the competitive edge
# ================================================
#
# Top N Summary
# -------------
# Budd also offers some insight into the people and projects he's keeping an eye on, or rather, as he explains, keeping a look out for — the next big things probably aren't yet on our radar, he says. We see a lot of companies trying to mimic successful products, but they get them fundamentally wrong. Often, if you're just following on the trends, by the time you've copied somebody's application, another one will come out. Subscribe to the O'Reilly Radar Podcast
#  TuneIn , iTunes , SoundCloud , RSS
#
#
#  Your customers aren't who you think they are
#  One of the design philosophies embraced at Clearleft traces back to a value list on the Edenspiekermann design agency website, Budd says: "You're not our customer; your clients are our customer. I think that if design was failing, these agencies would be going out of business because there's no market.
#
# Mean Scored Summary
# -------------------
# Budd also offers some insight into the people and projects he's keeping an eye on, or rather, as he explains, keeping a look out for — the next big things probably aren't yet on our radar, he says. ...
#  One of the reasons, I think, is that design is one of the few areas of the technology space, and the Web space, and the digital space that has a competitive advantage because it's really easy to copy an application technology when it launches, and create sort of a 'me-too' product. We see a lot of companies trying to mimic successful products, but they get them fundamentally wrong. Often, if you're just following on the trends, by the time you've copied somebody's application, another one will come out. Subscribe to the O'Reilly Radar Podcast
#  TuneIn , iTunes , SoundCloud , RSS
#
#
#  Your customers aren't who you think they are
#  One of the design philosophies embraced at Clearleft traces back to a value list on the Edenspiekermann design agency website, Budd says: "You're not our customer; your clients are our customer. Ultimately, what we're trying to do is we're trying to empathize with the user and trying to put the user's needs first. " In his conversation with Treseler, Budd says it's actually quite the opposite situation, that companies like Capital One buying agencies like Adaptive Path aren't the portents of doom they may seem:
#  The reason that Adaptive Path were bought out wasn't necessarily because they were struggling to find work. I think that if design was failing, these agencies would be going out of business because there's no market. They might not be well-known bloggers, they might not be well-known Twitter or Pinterest personalities, but they're amazing designers with amazing products. Happening May 20, 2015.
#
# Four short links: 16 April 2015
# ===============================
#
# Top N Summary
# -------------
# DeepDive -- DeepDive is targeted to help users extract relations between entities from data and make inferences about facts involving the entities. DeepDive can process structured, unstructured, clean, or noisy data and outputs the results into a database. From the Vault: Watching (and re-watching) “The Mother of All Demos” -- “I wish there was more about the social vision for computing—I worked with him for a long time, and Doug was always thinking ‘how can we collectively collaborate,’ like a sort of rock band.”
#  Running Kafka at Scale (LinkedIn Engineering) -- This tiered infrastructure solves many problems, but it greatly complicates monitoring Kafka and assuring its health. While a single Kafka cluster, when running normally, will not lose messages, the introduction of additional tiers, along with additional components such as mirror makers, creates myriad points of failure where messages can disappear. 3D Printing Titanium, and the Bin of Broken Dreams -- you will learn HUGE amounts on the challenges of real-world manufacturing by reading this.
#
# Mean Scored Summary
# -------------------
# From the Vault: Watching (and re-watching) “The Mother of All Demos” -- “I wish there was more about the social vision for computing—I worked with him for a long time, and Doug was always thinking ‘how can we collectively collaborate,’ like a sort of rock band.”
#  Running Kafka at Scale (LinkedIn Engineering) -- This tiered infrastructure solves many problems, but it greatly complicates monitoring Kafka and assuring its health. While a single Kafka cluster, when running normally, will not lose messages, the introduction of additional tiers, along with additional components such as mirror makers, creates myriad points of failure where messages can disappear.
#
# Zeta Architecture: Hexagon is the new circle
# ============================================
#
# Top N Summary
# -------------
# [caption id="attachment_75730" align="aligncenter" width="570"] Image courtesy of Jim Scott. Omega is their scheduler , and it is the crux of their dynamic distributed resource management. [caption id="attachment_75731" align="aligncenter" width="570"] Image courtesy of Jim Scott. [caption id="attachment_75732" align="aligncenter" width="570"] Web server before Zeta. [/caption]
#
#  [caption id="attachment_75733" align="aligncenter" width="570"] Web server after Zeta.
#
# Mean Scored Summary
# -------------------
# Following a bit of history and a description of the architecture, I'll use Google as an example and look at the way the company deploys technologies for Gmail. Many different architectural ideas came to my mind while I was in digital advertising. I was missing global resource management. Real-time data storage — This supports the need for high-speed business applications through the use of real-time databases. These solution architectures generally encompass a higher level interaction amongst common algorithms or libraries, software components, and business workflows. All too often, solution architectures are folded into enterprise architectures, but there is a clear separation with the Zeta Architecture. Enterprise applications — In the past, these applications would drive the rest of the architecture. [caption id="attachment_75730" align="aligncenter" width="570"] Image courtesy of Jim Scott. Omega is their scheduler , and it is the crux of their dynamic distributed resource management. Logs would still get generated, but now they would land on the distributed file system. No other changes required, log shipping goes away, and the data is immediately available to the compute model / execution engine for analytics or any other process the business needs. [caption id="attachment_75731" align="aligncenter" width="570"] Image courtesy of Jim Scott. [/caption]
#  If logs don’t have to be shipped, then technologies like Flume or Kafka can be removed from some application architectures. In the anecdote I shared at the beginning of this article, we used Flume as the solution. These days, priority number one seems to change fast and often, and this architecture supports a business that needs to change things instantly. [caption id="attachment_75732" align="aligncenter" width="570"] Web server before Zeta. Image courtesy of Jim Scott. [/caption]
#
#  [caption id="attachment_75733" align="aligncenter" width="570"] Web server after Zeta. Image courtesy of Jim Scott. [/caption]
#  Additional materials
#  If you’re interested in learning more, I have written a free downloadable technical white paper documenting the Zeta Architecture .
#
# Four short links: 15 April 2015
# ===============================
#
# Top N Summary
# -------------
# Facebook Biometrics Cache (Business Insider) -- Facebook has been accused of violating the privacy of its users by collecting their facial data, according to a class-action lawsuit filed last week. This data-collection program led to its well-known automatic face-tagging service. But it also helped Facebook create “the largest privately held stash of biometric face-recognition data in the world,” the Courthouse News Service reports. More concretely, clusters extracted from these time series are forced to obey a certain constraint that is pathologically unlikely to be satisfied by any data set, and because of this, the clusters extracted by any clustering algorithm are essentially random. “It feels like it’s slowing you down because you have to say everything three times,” van Rossum says.
#
# Mean Scored Summary
# -------------------
# Facebook Biometrics Cache (Business Insider) -- Facebook has been accused of violating the privacy of its users by collecting their facial data, according to a class-action lawsuit filed last week. But it also helped Facebook create “the largest privately held stash of biometric face-recognition data in the world,” the Courthouse News Service reports. “It feels like it’s slowing you down because you have to say everything three times,” van Rossum says.
#
# Rebooting a 1970s satellite with modern software and hardware
# =============================================================
#
# Top N Summary
# -------------
# [caption id="attachment_75766" align="aligncenter" width="570"]  The Arecibo Observatory in Puerto Rico, where Dennis Wingo and his team established contact with the ISEE-3 satellite. Solid returns to Fort Mason June 23–25, 2015. When Wingo re-established contact with the satellite, it was off course by 3,000 kilometers — after traveling 24 billion kilometers. The story is an excellent illustration of how software can replace physical complexity — one of the key themes we follow at the Solid conference , and Dennis will deliver a keynote at Solid San Francisco in June , where he'll talk about his extraordinary combination of techno-archaeology and modern computing. Episodes are edited by Brian Burge, with closing music by Thaddeus Bromstrup.
#
# Mean Scored Summary
# -------------------
# [caption id="attachment_75766" align="aligncenter" width="570"]  The Arecibo Observatory in Puerto Rico, where Dennis Wingo and his team established contact with the ISEE-3 satellite. Solid returns to Fort Mason June 23–25, 2015. When Wingo re-established contact with the satellite, it was off course by 3,000 kilometers — after traveling 24 billion kilometers.
#
# Beyond bitcoin and the blockchain to booming business
# =====================================================
#
# Top N Summary
# -------------
# The vision for bitcoin and the blockchain is unabashedly optimistic, though already it is being realized. In the medium term, there remain hurdles to overcome before blockchain technology can offer sufficiently compelling solutions for the complex financial and technological world we live in, but there is progress to date — and it’s promising. Ripple Labs has taken a very different approach with its protocol, permitting the decentralized transmission of practically any currency type — cryptographic or fiat — like an SMTP for money, and circumventing traditional payment networks. It behooves many in the digital currency community to seek out financial relationships early on to bridge the knowledge gap. For that reason, it behooves many in the digital currency community to seek out financial relationships early on to bridge the knowledge gap and invent even more disruptive products and processes.
#
# Mean Scored Summary
# -------------------
# The vision for bitcoin and the blockchain is unabashedly optimistic, though already it is being realized. In the medium term, there remain hurdles to overcome before blockchain technology can offer sufficiently compelling solutions for the complex financial and technological world we live in, but there is progress to date — and it’s promising. Blockchain-based remittance vehicles offered by Coins.ph , BitPagos , and BitPesa , though early stage, aim to take a chunk of the $450 billion remittance industry by offering speedier, more efficient, and cheaper alternatives to traditional solutions. Ripple Labs has taken a very different approach with its protocol, permitting the decentralized transmission of practically any currency type — cryptographic or fiat — like an SMTP for money, and circumventing traditional payment networks. What’s more, the U.S. regulatory regime is warming to digital currency. It behooves many in the digital currency community to seek out financial relationships early on to bridge the knowledge gap. For that reason, it behooves many in the digital currency community to seek out financial relationships early on to bridge the knowledge gap and invent even more disruptive products and processes.
#
# Four short links: 14 April 2015
# ===============================
#
# Top N Summary
# -------------
# Pycon 2015: Technical Debt, The Monster in Your Closet (YouTube) -- excellent talk from PyCon. A/A Testing -- In an A/A test, you run a test using the exact same options for both “variants” in your test. That’s right, there’s no difference between “A” and “B” in an A/A test. It sounds stupid, until you see the “results.” (via Nelson Minar )
#  NSA Declares War on General-Purpose Computing (BoingBoing) -- NSA director Michael S Rogers says his agency wants "front doors" to all cryptography used in the USA, so that no one can have secrets it can't spy on -- but what he really means is that he wants to be in charge of which software can run on any general purpose computer. (via Paul Walker )
#
# Mean Scored Summary
# -------------------
# Pycon 2015: Technical Debt, The Monster in Your Closet (YouTube) -- excellent talk from PyCon.
#
# Four short links: 13 April 2015
# ===============================
#
# Top N Summary
# -------------
# The Great Reversal in the Demand for Skill and Cognitive Tasks (PDF) -- The only difference with more conventional models of skill-biased technological change is our modelling of the fruits of cognitive employment as creating a stock instead of a pure flow. This slight change causes technological change to generate a boom and bust cycle, as is common in most investment models. We also incorporated into this model a standard selection process whereby individuals sort into occupations based on their comparative advantage. provinces -- state and province lists for (some) countries. Trigger warning: candid descriptions of real immature software organisations.
#
# Mean Scored Summary
# -------------------
# The Great Reversal in the Demand for Skill and Cognitive Tasks (PDF) -- The only difference with more conventional models of skill-biased technological change is our modelling of the fruits of cognitive employment as creating a stock instead of a pure flow. This slight change causes technological change to generate a boom and bust cycle, as is common in most investment models. We also incorporated into this model a standard selection process whereby individuals sort into occupations based on their comparative advantage.
#
# 5 reasons why Python is a popular teaching language
# ===================================================
#
# Top N Summary
# -------------
# Compared to most other languages, Python’s syntax (how it is written) is simple and easy to understand. In Python, you use something called a list. In Python, you use something called a dictionary. location = world[place]
#  # Print the location's description and exits. elif direction in location['exits']:
#   # Set new place in world.
#
# Mean Scored Summary
# -------------------
# This chapter will hopefully open your eyes to how easy it is to learn Python (and thus, why it is such a popular choice as a teaching language). Code readability
#  When I write a to-do list on a piece of paper, it looks something like this:
#
# Shopping
# Fix broken gutter
# Mow the lawn
#  This is an obvious list of items. [/caption]
#  Notice how the lines of code implementing the say_hello function are indented just like the to-do list. Compared to most other languages, Python’s syntax (how it is written) is simple and easy to understand. For example, the following code written using the Perl programming language will look for duplicate words in a text document:
#
# print "$. Obvious simplicity
#  The simple core concepts and knowledge required to write Python code will get you quite far. In Python, you use something called a list. In Python, you use something called a dictionary. If I want to look up a capital city for a certain country, I reference the county’s name in square brackets next to the object named capital_cities :
#
# capital_cities['China']
# 'Beijing'
#
#  Many programming languages have data structures that work like Python’s lists and dictionaries; some of them do the obvious thing and call such constructs “lists” and “dictionaries”; some other languages make using such constructs as easy and obvious as Python (although many don’t). As mentioned earlier, Python also does the expected thing. While this may sound like a good idea, it means that faulty code like that attempted above will be executed without any error and cause uncertain results (after all, what is the answer of summing a dictionary and a list?). Guess what happens if you try to sum an empty array with an object in JavaScript (we switch around the summed terms). Most of the program consists of either comments to explain how it works or is a data dictionary that describes the game world. """
# A very simple adventure game written in Python 3. while True:
#  # Get the current location from the world. location = world[place]
#  # Print the location's description and exits. print(location['description'])
#  print('Exits:')
#  print(', '.join(location['exits'].keys()))
#  # Get user input. direction = input('Where now? ').strip().lower()
#  # Parse the user input...
#  if direction == 'quit':
#   print('Bye! elif direction in location['exits']:
#   # Set new place in world. print("I don't understand! Open extensibility
#  Despite the powerful simplicity of the core language, programmers often need to reuse existing library modules of code to achieve a common task. For example, a common task is to retrieve data from a website. There is also a well-understood and simple process by which new features of the language are proposed and implemented: the Python Enhancement Proposals (PEPs) . This is important in an educational context because Python works on the computers used in schools. [/caption]
#  The important educational advantage is continuity. Humanity
#  While not a strict feature of the language, Python’s community, history, and philosophy often shines through code written in Python. The odd Monty Python reference (the website that hosts third-party Python modules is called the Cheese Shop after the sketch about a cheese shop with no cheese), a playful sense of fun (for instance, “the PyPy project” is so named because it is a high-performance version of Python written in Python), and other apparent eccentricities bestow upon Python the appearance of an approachable and interesting language.
#
# In design, what we really need is critical thinking
# ===================================================
#
# Top N Summary
# -------------
# Sometimes we might get a gut reaction. Essentially, it’s a gut reaction. Examples of this kind of feedback often take the form of:
#  That’s wonderful! It’s this form of feedback that is most helpful to us in understanding the impact of our design decisions. Good critique is comprised of three key details:
#
#  It identifies a specific aspect of the idea or a design decision in the creation being analyzed.
#
# Mean Scored Summary
# -------------------
# One of the most common ways design discussions are initiated is for a team member to ask for feedback on something they’ve created or an idea they have. They might just grab someone at a nearby desk because they want to take a break from putting something together and think about what they’ve done so far. Or it could be part of a planned milestone or date in the project’s timeline, often called Design Reviews. It is the system’s response to what the user has done. Feedback is a reaction that occurs as a result of us doing something. Sometimes we might get a gut reaction. Three kinds of feedback
#  As Aaron and I have seen in our own experiences and through watching and working with other teams, there are key characteristics that separate three forms of feedback, all of which vary in their level of usefulness to us in the design process. Essentially, it’s a gut reaction. Examples of this kind of feedback often take the form of:
#  That’s wonderful! Are they looking at it the same way your potential users would? In many cases that’s also where it ends. We’ll talk more about problem solving and it’s impact later on in Chapter 3. When looking for feedback on our creations, what we should be working to understand is whether we think it’s true or not that what has been created and the method in which it’s been created will work to achieve those objectives. We’re looking for a form of analysis to take place. It’s this form of feedback that is most helpful to us in understanding the impact of our design decisions. Good critique is comprised of three key details:
#
#  It identifies a specific aspect of the idea or a design decision in the creation being analyzed. It relates that aspect or decision to an objective or best practice.
#
# Four short links: 10 April 2015
# ===============================
#
# Top N Summary
# -------------
# Exact Maximum Clique for Large or Massive Real Graphs -- explanation of how BBMCSP works. Using an array of instrumentation, Santos’ team is able to translate that interaction into data a computer can understand. Everything We Wish We'd Known About Building Data Products (DJ Patil and RusJan Belkin) -- Data is super messy, and data cleanup will always be literally 80% of the work. [...] "If you're not thinking about how to keep your data clean from the very beginning, you're fucked. Don’t be afraid to fail a deploy if you detect data quality issues.
#
# Mean Scored Summary
# -------------------
# Exact Maximum Clique for Large or Massive Real Graphs -- explanation of how BBMCSP works. Using an array of instrumentation, Santos’ team is able to translate that interaction into data a computer can understand. [...] "If you're not thinking about how to keep your data clean from the very beginning, you're fucked. Don’t be afraid to fail a deploy if you detect data quality issues.
#
# Cross-pollinating Web communities
# =================================
#
# Top N Summary
# -------------
# Creating great websites and applications demands collaboration among content creators, designers, and programmers. At the same time, though, often even in environments where resources are scarce, different perspectives can reinforce each other or create new possibilities. Creating great websites and applications demands collaboration among content creators, designers, and programmers. Sympathetically told, git's story fits the needs of many kinds of Web developers. One last group, often unheralded, is key to the Web's cross-pollination: a constant flow of beginners.
#
# Mean Scored Summary
# -------------------
# Creating great websites and applications demands collaboration among content creators, designers, and programmers. At the same time, though, often even in environments where resources are scarce, different perspectives can reinforce each other or create new possibilities. Roy Fielding's 2000 UC Irvine dissertation, " Architectural Styles and
# the Design of Network-based Software Architectures " sounds pretty abstract, but the chapter on "Representational State Transfer (REST)" might sound familiar. Creating great websites and applications demands collaboration among content creators, designers, and programmers. I always like to go to "Git for Designers" talks. Sympathetically told, git's story fits the needs of many kinds of Web developers. Accessibility folks rarely set out to be specialists in Web architecture, in the details of browsers, or in programmer education. One last group, often unheralded, is key to the Web's cross-pollination: a constant flow of beginners.
#
# Open source won, so what&#8217;s next?
# ======================================
#
# Top N Summary
# -------------
# Twenty years ago, open source was a cause. Software engineers now use open source frameworks, languages, and tools in almost all projects. It seems open source has indeed won, but let's not gloat; let's make things even better. New libraries and frameworks augment these and other open source languages by giving software engineers tools to solve problems quickly. However, languages with their libraries and frameworks are but the tools to get things done.
#
# Mean Scored Summary
# -------------------
# Twenty years ago, open source was a cause. Software engineers now use open source frameworks, languages, and tools in almost all projects. It seems open source has indeed won, but let's not gloat; let's make things even better. Open source has made many great changes to software possible, but the spirit of the founding community goes well beyond code. New libraries and frameworks augment these and other open source languages by giving software engineers tools to solve problems quickly. However, languages with their libraries and frameworks are but the tools to get things done. In the past, we've organized OSCON's tracks by language. This year, you'll see that we've set the tracks so they reflect what you, the software engineer, need to get things done. We'll look at the ways a new generation of tools and approaches can help you work. We'll present ideas on how to fail fast, say “no,” overcome impostor syndrome, and integrate your work into the open source community. This year, we'll focus on company culture via Cultivate , a two-day event at OSCON. It's been at the heart of what we do for almost 18 years.

# %% [markdown]
# ## Example 7. Visualizing document summarization results with HTML output

# %%
import os
import json
import nltk
import numpy
from IPython.display import IFrame
from IPython.core.display import display

BLOG_DATA = "resources/ch05-webpages/feed.json"

HTML_TEMPLATE = """<html>
    <head>
        <title>%s</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>%s</body>
</html>"""

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:
   
    # Uses previously defined summarize function.
    post.update(summarize(post['content']))

    # You could also store a version of the full post with key sentences marked up
    # for analysis with simple string replacement...

    for summary_type in ['top_n_summary', 'mean_scored_summary']:
        post[summary_type + '_marked_up'] = '<p>%s</p>' % (post['content'], )
        for s in post[summary_type]:
            post[summary_type + '_marked_up'] = \
            post[summary_type + '_marked_up'].replace(s, '<strong>%s</strong>' % (s, ))

        filename = post['title'].replace("?", "") + '.summary.' + summary_type + '.html'
        f = open(os.path.join('resources', 'ch05-webpages', filename), 'w')
        html = HTML_TEMPLATE % (post['title'] + \
          ' Summary', post[summary_type + '_marked_up'],)
              
        f.write(html.encode('utf-8'))
        f.close()

        print "Data written to", f.name

# Display any of these files with an inline frame. This displays the
# last file processed by using the last value of f.name...

print "Displaying %s:" % f.name
display(IFrame('files/%s' % f.name, '100%', '600px'))
# Out:
# Data written to resources/ch05-webpages/6 best practices for giving a product critique.summary.top_n_summary.html
# Data written to resources/ch05-webpages/6 best practices for giving a product critique.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 17 April 2015.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 17 April 2015.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Experience design gives you the competitive edge.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Experience design gives you the competitive edge.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 16 April 2015.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 16 April 2015.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Zeta Architecture: Hexagon is the new circle.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Zeta Architecture: Hexagon is the new circle.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Four short links: 15 April 2015.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 15 April 2015.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Rebooting a 1970s satellite with modern software and hardware.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Rebooting a 1970s satellite with modern software and hardware.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Beyond bitcoin and the blockchain to booming business.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Beyond bitcoin and the blockchain to booming business.summary.mean_scored_summary.html
# Data written to resources/ch05-webpages/Four short links: 14 April 2015.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 14 April 2015.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Four short links: 13 April 2015.summary.top_n_summary.html
# Data written to
#  resources/ch05-webpages/Four short links: 13 April 2015.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/5 reasons why Python is a popular teaching language.summary.top_n_summary.html
# Data written to resources/ch05-webpages/5 reasons why Python is a popular teaching language.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/In design, what we really need is critical thinking.summary.top_n_summary.html
# Data written to resources/ch05-webpages/In design, what we really need is critical thinking.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Four short links: 10 April 2015.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Four short links: 10 April 2015.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Cross-pollinating Web communities.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Cross-pollinating Web communities.summary.mean_scored_summary.html
# Data written to
#  resources/ch05-webpages/Open source won, so what&#8217;s next.summary.top_n_summary.html
# Data written to resources/ch05-webpages/Open source won, so what&#8217;s next.summary.mean_scored_summary.html
# Displaying resources/ch05-webpages/Open source won, so what&#8217;s next.summary.mean_scored_summary.html:
#         <iframe
#             width="100%"
#             height=600px"
#             src="files/resources/ch05-webpages/Open source won, so what&#8217;s next.summary.mean_scored_summary.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Example 8. Extracting entities from a text with NLTK

# %%
import nltk
import json

BLOG_DATA = "resources/ch05-webpages/feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:

    sentences = nltk.tokenize.sent_tokenize(post['content'])
    tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
    pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]

    # Flatten the list since we're not using sentence structure
    # and sentences are guaranteed to be separated by a special
    # POS tuple such as ('.', '.')

    pos_tagged_tokens = [token for sent in pos_tagged_tokens for token in sent]

    all_entity_chunks = []
    previous_pos = None
    current_entity_chunk = []
    for (token, pos) in pos_tagged_tokens:

        if pos == previous_pos and pos.startswith('NN'):
            current_entity_chunk.append(token)
        elif pos.startswith('NN'):
            if current_entity_chunk != []:

                # Note that current_entity_chunk could be a duplicate when appended,
                # so frequency analysis again becomes a consideration

                all_entity_chunks.append((' '.join(current_entity_chunk), pos))
            current_entity_chunk = [token]

        previous_pos = pos

    # Store the chunks as an index for the document
    # and account for frequency while we're at it...

    post['entities'] = {}
    for c in all_entity_chunks:
        post['entities'][c] = post['entities'].get(c, 0) + 1

    # For example, we could display just the title-cased entities

    print post['title']
    print '-' * len(post['title'])
    proper_nouns = []
    for (entity, pos) in post['entities']:
        if entity.istitle():
            print '\t%s (%s)' % (entity, post['entities'][(entity, pos)])
    print
# Out:
# 6 best practices for giving a product critique
# ----------------------------------------------
# 	Remember (2)
# 	Flickr (1)
# 	Bad Critique Selfish The (1)
# 	Hold (2)
# 	Think (1)
# 	Assumptions (1)
# 	Chapter (3)
# 	Aaron (2)
# 	Dan G (1)
# 	Yup (1)
# 	Difficult People (1)
# 	Ask (1)
# 	Tell (1)
# 	Incomplete For (1)
# 	Adam Connor (1)
# 	Situations (1)
# 	Talk (1)
# 	Creative Commons (1)
# 	Cropped (1)
# 	Get (2)
# 	Designing (1)
# 	Part (1)
# 	Most (1)
# 	Characteristics (1)
# 	Good (2)
# 	Twitter (1)
# 	Ask (1)
# 	Examples (1)
# 	Use (1)
# 	Internet (1)
# 	Chances (1)
# 	Chapter (1)
# 	Christmas (1)
# 	Find (1)
# 	Design (1)
# 	Recall (1)
# 	Part (1)
# 	Within (1)
# 	Critiquing (1)
# 	Intent (1)
# 	Nobody (1)
# 	Giving (1)
# 	Download (2)
# 	Discussing Design (1)
# 	Things (1)
# 	Challenging (1)
# 	Chapter (1)
# 	Facebook (1)
# 	Aaron Irizarry (1)
#
# Four short links: 17 April 2015
# -------------------------------
# 	How (1)
# 	Raft Consensus (1)
# 	Bruce Sterling (1)
# 	Scientists (1)
# 	Communicate (1)
# 	Open Access (1)
# 	Machines (2)
# 	Cognition (1)
# 	Humans (1)
# 	Cats (1)
# 	Siri (1)
# 	Convergence (1)
# 	Norm (1)
# 	Siri (1)
# 	Interview (1)
#
# Experience design gives you the competitive edge
# ------------------------------------------------
# 	Twitter (1)
# 	Mary Treseler (1)
# 	Cropped (1)
# 	View (1)
# 	Radar Podcast (1)
# 	Flickr (1)
# 	Creative Commons (1)
# 	Andy Budd (1)
# 	May (1)
# 	Clearleft (3)
# 	Capital (1)
# 	Adaptive Path (1)
# 	Pinterest (1)
# 	Budd (7)
# 	Subscribe (2)
# 	Treseler (1)
# 	Design (1)
# 	Adaptive Path (1)
# 	Designers (1)
# 	Web (2)
# 	Budd (2)
# 	Edenspiekermann (1)
# 	Clearleft (1)
# 	People (1)
# 	Capital (1)
# 	Design (1)
# 	Radar Podcast (1)
# 	Portents (1)
#
# Four short links: 16 April 2015
# -------------------------------
# 	Broken Dreams (1)
# 	Doug (1)
# 	Kafka (1)
# 	) “The (1)
# 	Kafka (2)
# 	Bin (1)
# 	Printing Titanium (1)
# 	Mother (1)
# 	Watching (1)
# 	Vault (1)
# 	Running Kafka (1)
# 	All Demos” (1)
#
# Zeta Architecture: Hexagon is the new circle
# --------------------------------------------
# 	Gmail (2)
# 	Chicago (1)
# 	Amazon (2)
# 	Google (1)
# 	Apache Mesos (1)
# 	In (1)
# 	Jim Scott (4)
# 	Traffic (1)
# 	Additional (1)
# 	Chris Ford (1)
# 	Web (2)
# 	Cropped (1)
# 	Google (2)
# 	Borg (1)
# 	Flume (1)
# 	Borg (1)
# 	Data (1)
# 	Kafka (1)
# 	Omega (2)
# 	Logs (1)
# 	Zeta Architecture (5)
# 	Allows (1)
# 	Google (5)
# 	Different (1)
# 	Better (1)
# 	Enterprise (2)
# 	Web (2)
# 	Black Friday (1)
# 	Creative Commons (1)
# 	Origin (1)
# 	Gmail (1)
# 	Building (1)
# 	Zeta (2)
# 	Flume (2)
# 	Flickr (1)
# 	Deployment (1)
# 	Zeta Architecture (1)
# 	Image (2)
#
# Four short links: 15 April 2015
# -------------------------------
# 	Dropbox (1)
# 	Imperiled (1)
# 	Toolkits (1)
# 	Oceans (1)
# 	Google (1)
# 	Earth (1)
# 	Meaningless (1)
# 	Facebook Biometrics Cache ( Business Insider ) (1)
# 	Time Series Sequences (1)
# 	Amen (1)
# 	Robots (1)
# 	Facebook (1)
# 	Clustering (1)
# 	Clustering (1)
# 	Rossum (1)
# 	Courthouse News Service (1)
# 	( Wired ) (1)
# 	Facebook (1)
#
# Rebooting a 1970s satellite with modern software and hardware
# -------------------------------------------------------------
# 	Brian Burge (1)
# 	Solid Podcast (1)
# 	Solid San Francisco (1)
# 	Puerto Rico (1)
# 	Solid Conference (1)
# 	Wikipedia (1)
# 	Fort Mason June (1)
# 	Jon Bruner (1)
# 	International Sun/Earth (1)
# 	Solid (2)
# 	David Cranor (1)
# 	Internet (1)
# 	Dennis Wingo (2)
# 	View (1)
# 	Subscribe (2)
# 	Wingo (2)
# 	Things (1)
# 	Dennis (4)
# 	Skycorp (1)
# 	Ready (1)
# 	Puerto Rico (1)
# 	Solid (2)
# 	June (1)
# 	Episodes (1)
# 	Arecibo Observatory (2)
# 	S (1)
# 	Ettus (1)
# 	In (1)
#
# Beyond bitcoin and the blockchain to booming business
# -----------------------------------------------------
# 	Financial (1)
# 	Editor (1)
# 	Finance (1)
# 	Blockchain (1)
# 	Filament (1)
# 	Creative Commons (1)
# 	Hiroyuki Takeda (1)
# 	Federal Reserve (1)
# 	Internet (1)
# 	Cropped (1)
# 	Maidsafe (1)
# 	New York Stock Exchange (1)
# 	Companies (1)
# 	California (1)
# 	Things (1)
# 	Global Shopping Cart (1)
# 	Storj (1)
# 	Bitcoin (1)
# 	Ripple Labs (1)
# 	Fidor Bank ( Germany ) (1)
# 	Mutatis (1)
# 	Remittance (1)
# 	Federal Election Committee (1)
# 	Ethereum (1)
# 	Flickr (1)
# 	Services (1)
# 	Cross River Bank ( New Jersey ) (1)
# 	Banks (1)
# 	Coinbase (1)
# 	Factom (1)
# 	U.S. (1)
#
# Four short links: 14 April 2015
# -------------------------------
# 	The Monster (1)
# 	Debt (1)
# 	A/A (1)
# 	Michael S Rogers (1)
# 	John (1)
# 	American Mathematical Association (1)
# 	In (1)
# 	See (1)
# 	Pycon (1)
# 	A/A Testing (1)
#
# Four short links: 13 April 2015
# -------------------------------
# 	Demand (1)
# 	Great Reversal (1)
# 	Code (1)
# 	Cultural Analytics (1)
# 	The (2)
# 	Simon (1)
# 	Symptom (1)
# 	Telephone (1)
# 	Trigger (1)
# 	Just (1)
# 	Skill (1)
#
# 5 reasons why Python is a popular teaching language
# ---------------------------------------------------
# 	Parse (1)
# 	File (1)
# 	Cheese Shop (1)
# 	Object ] (2)
# 	Editor (1)
# 	Monty Python (1)
# 	Traceback (1)
# 	Set (2)
# 	Java (1)
# 	Python (10)
# 	Linux (1)
# 	Anything (1)
# 	Furthermore (2)
# 	Anyone (1)
# 	Pandas (1)
# 	Nicholas Tollervey (1)
# 	Start (1)
# 	Instagram (1)
# 	Micro Python (1)
# 	Check (2)
# 	C (1)
# 	Kingdom (1)
# 	Python (22)
# 	Compared (1)
# 	'Athens (1)
# 	Nicholas Hello (1)
# 	Code (1)
# 	Perl (2)
# 	Django (1)
# 	Education (1)
# 	I/O (1)
# 	Break (1)
# 	Learning (1)
# 	Get (2)
# 	English (1)
# 	Borrow (1)
# 	Shopping Fix (1)
# 	Return (1)
# 	Mozilla (1)
# 	Bye (1)
# 	Furthermore (2)
# 	Python Anywhere (1)
# 	Print (1)
# 	Raspberry Pi (1)
# 	'Germany (1)
# 	Nicholas [ (1)
# 	'Mow (1)
# 	Find (1)
# 	Django (2)
# 	Eggs Bacon Tomatoes Fix (1)
# 	Python ) (1)
# 	Users (1)
# 	Education (1)
# 	'Russia (1)
# 	Natural Language Tool Kit ) (1)
# 	Exits (4)
# 	'Fix (1)
# 	National Geographic (1)
# 	Python (6)
# 	True (1)
# 	Students (1)
# 	Mow (2)
# 	Players (1)
# 	Download (2)
# 	The Guardian (1)
# 	Shopping (1)
# 	Notice (1)
# 	September (1)
# 	Microsoft Office (1)
# 	Python ( (2)
# 	'Exits (1)
# 	Despite (1)
# 	Humanity (1)
# 	Microsoft Windows (1)
# 	Web (3)
# 	Open (1)
# 	Guess (1)
# 	Consider (1)
# 	Raspberry Pi (1)
#
# In design, what we really need is critical thinking
# ---------------------------------------------------
# 	Direction (1)
# 	Sometime (1)
# 	Cropped (1)
# 	Experience Design (1)
# 	Great (1)
# 	Creative Commons (1)
# 	Critique (2)
# 	Patrick Hoesly (1)
# 	Design Reviews (1)
# 	Chapter (3)
# 	Internet (1)
# 	Reaction (1)
# 	Aaron (1)
# 	Download (2)
# 	Discussing Design (1)
# 	Are (1)
# 	Flickr (1)
# 	Things (1)
# 	Reactions (1)
# 	Designing (1)
# 	Feedback (3)
# 	Designers (1)
# 	Examples (1)
# 	Critical (1)
# 	Chapters (1)
# 	Aaron Irizarry (1)
# 	Adam Connor (1)
# 	Design (1)
# 	Good (2)
#
# Four short links: 10 April 2015
# -------------------------------
# 	Human Touch (1)
# 	Large (1)
# 	Prostheses (1)
# 	Python (1)
# 	Everything (1)
# 	Veronica J. Santos (1)
# 	Santos’ (1)
# 	Massive Real Graphs (1)
# 	Maximum Clique (1)
# 	Data (1)
# 	Robots (1)
# 	Products (1)
#
# Cross-pollinating Web communities
# ---------------------------------
# 	Design (1)
# 	Architectural Styles (1)
# 	Git (1)
# 	Diffs (1)
# 	Roy Fielding (1)
# 	Flickr (1)
# 	Marketers (1)
# 	Software Architectures (1)
# 	“Content” (1)
# 	Berit Watkin (1)
# 	Branches (1)
# 	World Wide Web Consortium ( W3C ) (1)
# 	Fielding (1)
# 	Cryptographic (1)
# 	Web (8)
# 	Pull (1)
# 	Netscape (1)
# 	Web (1)
# 	Let (1)
# 	Have (1)
# 	Mozilla (1)
# 	Ted Nelson (1)
# 	Accessibility (2)
# 	Photo (1)
# 	Creative Commons License (1)
# 	Linux (1)
# 	Lousy (1)
# 	Hypermedia (1)
# 	Designers (1)
# 	People (1)
# 	Delta (1)
# 	Web (11)
# 	Twitter ( @ (1)
# 	Today (1)
# 	Battles (1)
# 	Linus Torvalds (1)
# 	World Wide Web (1)
#
# Open source won, so what&#8217;s next?
# --------------------------------------
# 	Making (1)
# 	Well (1)
# 	Identity (1)
# 	Mobility (1)
# 	Data (1)
# 	Collaboration (1)
# 	Python (1)
# 	Java (1)
# 	Software (1)
# 	Cultivate (1)
# 	Foundations (1)
# 	Today (1)
# 	Solve (1)
# 	Scale (1)
# 	Harness (1)
# 	Languages (1)
# 	Cultivate (1)
# 	Software (2)
# 	Architecture (1)
# 	Iron Throne (1)
# 	Craft (1)
# 	Pieces (1)
# 	Design (1)
# 	Open (2)
# 	New (1)
# 	From (1)
# 	Twenty (1)
# 	Learn (1)
# 	Protect (1)
# 	Ruby (1)

# %% [markdown]
# ## Example 9. Discovering interactions between entities

# %%
import nltk
import json

BLOG_DATA = "resources/ch05-webpages/feed.json"

def extract_interactions(txt):
    sentences = nltk.tokenize.sent_tokenize(txt)
    tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
    pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]

    entity_interactions = []
    for sentence in pos_tagged_tokens:

        all_entity_chunks = []
        previous_pos = None
        current_entity_chunk = []

        for (token, pos) in sentence:

            if pos == previous_pos and pos.startswith('NN'):
                current_entity_chunk.append(token)
            elif pos.startswith('NN'):
                if current_entity_chunk != []:
                    all_entity_chunks.append((' '.join(current_entity_chunk),
                            pos))
                current_entity_chunk = [token]

            previous_pos = pos

        if len(all_entity_chunks) > 1:
            entity_interactions.append(all_entity_chunks)
        else:
            entity_interactions.append([])

    assert len(entity_interactions) == len(sentences)

    return dict(entity_interactions=entity_interactions,
                sentences=sentences)

blog_data = json.loads(open(BLOG_DATA).read())

# Display selected interactions on a per-sentence basis

for post in blog_data:

    post.update(extract_interactions(post['content']))

    print post['title']
    print '-' * len(post['title'])
    for interactions in post['entity_interactions']:
        print '; '.join([i[0] for i in interactions])
    print
# Out:
# 6 best practices for giving a product critique
# ----------------------------------------------
# Download; copy; Designing; Internet; Things; collection; chapters; Design
# post; excerpt; Discussing Design; Adam Connor; Aaron Irizarry; books
# sides; roles; critique; (; s
# creator; presenter; whatever; perspectives; information; critique; process; act
# (; s; critique; creation; thoughts
# Within; roles; aspect; intention
# Intent; initiator; conversation; separates; critiques; feedback; discussions
# discussions; intent; participant
# intent; side; problems; designs; ability
# critique; intent; decisions; made; product’s; )
# [ caption id=; attachment_74387; align=; alignright; width=; Download
# [ /caption; Giving; critique; intent; creator understand; impacts; choices; regard; effectiveness
# acts; intention; information; perspectives; critique
#
# meetings; thoughts; something; design; process; project; ex; postmortem; time; discussions; action; changes; desire
# Part; critiques
# case; everything; critique; modification; design; participants; discussion; role; improving; design; ability
# beginning; critique; giver
# critique; critique; right intent; improvement; creation; helping; creator understand; success; design; choices
# feedback; discussions; mindset
# understand; critique; looks; look; characteristics
# tips; handling; feedback; critique; Chapter; Critiquing; Difficult People; Challenging
# Characteristics; Bad Critique Selfish The; intentions
# goals; desires; attention; expense; team; individuals; creator
# critique; motivation; giver; attract attention; smarter
# examples; networks; Twitter; Facebook; whenever; change; app; device
# feature; something; people; decisions; things; situations; commenters; cursory understanding; designer; team
#
# (; Aaron; people; someone
# showing; others; community; organization
# type; feedback; happens; project
# work; colleague
# kind; feedback; ideas; design; chance
# feedback; way; design; (; cases
# Aaron; believers; idea; team; members; role; opportunity; ideas; path
# discuss; Chapter; place; exploring
#
# group; mindset; done
# people; people; always; feedback
# someone; feedback; it’s; unwise; conversation; opportunity
# someone; people; creation; word
# order; receiver; process; use; critique
# team member’s desk; meeting; channels; communication; breakdowns; paints; person; Incomplete For; critique; creator; s; outcome; reaction; element; creation
# feedback; form; things; think; button
# Nobody; type; feedback; form; feedback
# thinking; design
# order; critiques; explanation; giver; reaction; foresees
# example; page design; leads; eye; left side; screen; call-to-action.”; Good
# behind; feedback; comment; creator
# creator; understanding; alternatives
#
# case; critique; creator; something
#
# Good; critique; tries; problem; focus
#
# critique; feedback; giver
# heard horror; stories; kind; feedback; designs; apart; aspect isn’t; feedback giver “likes.”; example; design; gets; color scheme; reminds; stakeholder; Christmas; sweater
#
# relevance; work we’re
# kind; feedback; nothing; creation; regard
# case; team; members; stakeholders; position
# situations; team; tastes; project; user
# practices; critique; intent; done; teams; processes; product; critique; ability; relationships; collaboration; productivity
# order; critique; practices
#
# Get; information; feedback; show; interest
# Chances; feedback; creator; s; explanation
# understanding; objectives; elements; design; put
#
#
#
# asking; questions; information; analysis
# done; way; creator; work; thinking
# Examples; questions; objectives; aspect; element
# options; [
#
# influencers; constraints
# Remember; purpose; questions; creator; information; talking; thought process
# extent; questions
#
# Use lighter; “tell; Use
# Hold; reactions
#
# work; things; “that’s; “I don’t; get
# Hold; reactions; remember; reactions
# Ask; reacting
# Ask; presenters
#
# objectives; product; audience
#
# feedback; product’s; practices; reaction; preferences; place
# feedback; practice; preference; practice
#
#
# cases; feedback
# kinds; thoughts; determining; objectives; constraints; project
# something; critique; something; needs; discussion
#
# Find; thinking; constraints
# assume; ass; Most; line; times
# It’s; father’s favorites; it’s
# Assumptions; things
# assumptions; form; thoughts; questions
# participants; discussion go; way; work; ideas; work
# assumptions; critique; constraint; constraints; designer; anything; feedback
#
#
#
#
# assumption; ask
#
#
#
# Get; touch; ask
# Recall; section; feedback; types
# critique isn’t; mindset; feedback; chances; be; cause; rift
# thoughts; someone’s; creation; feedback
# Tell; point
#
#
#
# culture; society; tendency; negatives; things; cause; get
#
# project meeting; design; discussions; it’s; —; majority
#
# Remember; critique
# It’s; design; it’s; objectives
#
# role; feedback”; critique; discussions; importance; strengths; mechanism; feedback easier
# structure; “OREO”; “sandwich”; method; offering; piece
# It’s; technique; Chapter; studies
# reasons; sure; critiques; discussion; aspects; design
# Part; process; decomposition; abstraction; ideas; ways
# It’s; way; concept; room; improvement
# aspects; product; design; creators; areas; abstract; concepts; elements; areas
# understanding; creator; s; design; critique; critique; aspect; design; quite; team didn’t see
#
#
# section; critique; feedback; that’s; preferences; objectives
# analyzing; product; aren’t representative
#
# design; it’s; expertise
# balance; aspect; design; compare; perspective; user’s; got
#
# shade; matter
# example; perspective; steps; flow
# interaction design perspective; redundancy; opportunities; Cropped; image; article; category; pages; Dan G; Flickr; Creative Commons
#
# Four short links: 17 April 2015
# -------------------------------
# SQLite; Raft Consensus; consensus algorithm; (
# Open Access; Norm; How; Scientists
# (; PLOS ); interviews; researchers; software; developers; aspects; online collaboration
# (; Jon Udell ) Meet DJ Patil; kind; moment
# Interview; Bruce Sterling; Convergence; Humans; Machines; computation; times
#
#
#
#
#
# Cognition; stuff; seeing; wants
#
#
#
#
#
#
# Siri; converging; house cat
# technologies; enthusiasts
#
# cat; ideal laboratory animal; transitions; convergences
#
#
# Experience design gives you the competitive edge
# ------------------------------------------------
# Subscribe; Radar Podcast; technologies; people; world
# week; Radar Podcast; Mary Treseler; chats; Andy Budd; partner; UX; designer
# conversation; circles; lessons; Clearleft; user; design
# Budd; insight; people; projects; eye; look; things
# Clearleft; user-experience design consultancy; years; Budd; lot; psychology; philosophy; design; designers; actions; world
# value; design; Budd; notes; years; surpass; prominence technology; technology; conferences; years
# developers; heroes; stack
#
#
# years; technology stack; technology; lot; rise; prototyping; tools; rises; libraries; frameworks; maturation
# nowadays; startup; product company; Web; space; advantage
# reasons; design; areas; technology space; Web; space; space; advantage; application technology; sort
# design; quality product
# lot; companies
# trends; time; somebody
# designers; update; months
#
# companies; adopt; approach; delight; products; increase; return
# companies; design; years
# Subscribe; Radar Podcast TuneIn; iTunes; SoundCloud; RSS Your; customers; design; philosophies; Clearleft; traces; value list; Edenspiekermann; design agency website; Budd; customer; clients
# Budd; notes; firm grasp; end user; clients; needs; stakeholder; design
# lens; user; failings; structure; approach; outlook
#
# user; user
# user; needs; needs; needs
# organization; needs; user; force; user; needs
#
# blog post; Budd; death; agency
# conversation; Treseler; Budd; situation; companies; Capital; agencies; Adaptive Path; portents; doom; reason; Adaptive Path
# anything; Capital; design; offer; talent
#
#
# lot; stuff; happening; moment; something; sign; wall
# agencies; design; agencies; impact
# design; agencies; business
# fact; business; market; bought
#
# Designers; brink; years; Budd; list; designers; things; today; difference; industry; designers; work; years
# Budd; eye; limelight; amazing designer; radar; things
#
# People; work; basements; bedrooms; spaces
# bloggers; Twitter; Pinterest; personalities; designers
# weird thing; people; ones; work
#
# individuals; number; people
#
# thing; richness; maturity
#
# Design; drives
# online format; conference; designers; share; knowledge; tools; techniques
#
# View; program; Cropped; image; Marja van Bochove; Flickr; Creative Commons
#
# Four short links: 16 April 2015
# -------------------------------
# DeepDive; DeepDive; users; relations; entities; data; inferences; facts
# DeepDive; data; outputs; results
# Vault; Watching; ) “The; Mother; All Demos”; wish; vision; computing—I; time; Doug; ’; sort; rock band.”; Running Kafka; Scale ( LinkedIn Engineering ); infrastructure; solves; problems; Kafka
# Kafka; cluster; messages; introduction; tiers; components; mirror; makers; points; failure
# addition; Kafka; clusters; health; means; messages; tiers; consumers
# Printing Titanium; Bin; Broken Dreams; HUGE; amounts; challenges; manufacturing
#
# Zeta Architecture: Hexagon is the new circle
# --------------------------------------------
# Data; processing
#
# Zeta Architecture; enterprise architecture; business; processes; defines; way; speed; data
# bit; history; description; architecture; Google; example; look; way; company; technologies
# Origin; story; motivation; variety; information; systems; career; classes
# capacity perspective; company
# problems; industry flow; sheer volume; transactions
# Traffic; hours; day; periods; capacity; peak
# solution space isn’t; Amazon; infrastructure; loads
# Amazon; advertising; Black Friday
# ideas; mind
# performance; advertising platform
# became; buzzword
# point; time; advertising company; “satisfied”; delay; changes; system; insight; effects
# year; company; change; log collection
#
# approach; business; performance; minutes; time; change; people
# people; taste; mouths; support
# implementation; architecture; place; months; company
# implementation; months; experience; architecture; colleagues; solution
#
# It’s; enough” doesn’t exist
# matter; time
#
# expectations; expectations; months; ramifications; pieces
#
# finger; MesosCon
# piece; architecture
#
# doors; ways; rest; pieces
# combination; pieces; sum
# components; descriptions; component view; architecture; goals
#
# components; architecture; components; file system; file system; applications; location; enables; rest
# data; storage; supports; need; business; applications; use
# compute model; execution engine; Different; groups; business; needs; requirements; meeting; demands; time; support; engines; models; needs
# Deployment; container management system; need; approach; deploying software; resource; consumers
# Solution architecture; focuses
#
# solution; architectures; level interaction amongst; algorithms; libraries; software; components
# solution; architectures; enterprise; architectures; separation
# Enterprise; applications; In; applications; rest
#
# rest; architecture; applications; components; business; goals
# resource management; Allows; allocation; resources; business; whatever task
# ideas; paper; things; representation; architecture
#
# Zeta Architecture; begotten; way; name
# visuals; implementation; details; architecture
# way; document; Google’s
# Google; document
# diagram; Google; technology stack; Gmail
# architecture; anyone; implements; Google; scale
# [ caption id=; attachment_75730; align=; aligncenter; width=; Image; courtesy
# [ /caption; couple; points; Google’s technologies
# Borg; project; Google; Google; it’s
# Omega; scheduler; crux
#
# Google; source; projects; Apache Mesos; cues
# solution architecture perspective; Gmail
# machine learning; concepts; products; Google
#
# Web; servers; logs; disk
# servers; data; jobs
# story; scale; lot; work; log
#
# file system; servers; Web
#
# changes; log shipping; data; compute model; execution engine; analytics; process
#
# [ caption id=; attachment_75731; align=; aligncenter; width=; Image; courtesy
# [ /caption; logs; Flume; Kafka; application
# technologies; technologies; use; cases; data
#
# anecdote; beginning; article; Flume
# coworkers; tune; Flume; log; lines; day
# thousands; hours; designing; building; solution; course; code base; configuration
#
# things; Zeta Architecture
# application architecture; concern; things; data; protection; schemes; data; recovery; failures; multiple; versions
# Zeta Architecture; application; architectures; supports
# parts means; failure
# Better; hardware utilization
# business; leveraging; set; resources; problem
# days; priority number; architecture; business
# [ caption id=; attachment_75732; align=; aligncenter; width=; Web; server
#
# [ /caption; caption; attachment_75733; align=; aligncenter; width=; Web; server
#
# [ /caption; Additional; materials; learning; paper
# executive summary; Building; Enterprise
# Cropped; image; Chris Ford; Flickr; Creative Commons
#
# Four short links: 15 April 2015
# -------------------------------
# Facebook Biometrics Cache ( Business Insider ); Facebook; violating; privacy; users; collecting; data; class-action lawsuit
#
# Facebook; “the; stash; face-recognition; data; world; Courthouse News Service
# Clustering; Time Series Sequences; Meaningless; PDF; Clustering; time; series subsequences
# clusters; time; series; constraint; data; clusters
# constraint; illustration
# claim; contribution; dozens
# claim; theorem; examples; set; experiments; reimplementations
#
# Toolkits; Mind ( MIT TR ); designer; Guido van Rossum; spent; years; Google; Dropbox; software company; size; way; chaos; language; programmer
# feels; it’s; everything; times; van
#
# Robots; Earth; Imperiled; Oceans; ( Wired ); feet; airliner; wings; tail fin; bears; message; INSTRUMENT PLEASE; DO NOT DISTURB.” All; it’s; epigram; drone; dock; weapon
#
# Rebooting a 1970s satellite with modern software and hardware
# -------------------------------------------------------------
# Subscribe; Solid; podcast; topics; Internet; Things; hardware; software; manufacturing; blurring
# [ caption id=; attachment_75766; align=; aligncenter; width=; Arecibo Observatory; Puerto Rico; Dennis Wingo; team; contact; ISEE-3
#
# [ /caption; In; episode; Solid Podcast; Dennis Wingo; founder; Skycorp; NASA McDonald; images; moon
# hour; techno-archaeology; exploits; arcane analog image-transmission; systems; NASA; engineers; Dennis; history
# teaser; today
# Ready; computing; analog challenge; Dennis; attention; reboot; International Sun/Earth; research satellite
# NASA; equipment; communicating; Dennis; set; ISEE-3; control system
# custom analog hardware; hardware
# Solid; returns
# Solid; covers; IoT; robotics; drones; wearables; materials; UX; design; fabrication; security
# attendee; bit mind blowing.”; View; program; Wingo; team; system; Ettus; radio; S; band signal; call; receiver
#
# missile; men
# Wingo; contact; course; kilometers; traveling
# story; excellent illustration; software; complexity; themes; Solid; conference; Dennis; keynote; Solid San Francisco; June; combination
# Subscribe; Solid Podcast TuneIn; iTunes; SoundCloud; RSS The Solid Podcast; Jon Bruner; David Cranor; focuses; people; ideas; technology
# Episodes; Brian Burge; music
#
# Beyond bitcoin and the blockchain to booming business
# -----------------------------------------------------
# Editor; note; post; part; investigation
# video compilation; event; Bitcoin
# vision; bitcoin
# technologists; venture; capitalists; institutions; regulators; transform; industries; services; data; management; Internet
# medium term; remain; hurdles; blockchain technology; solutions; complex; world; progress; date
# remittance; vehicles; BitPagos; BitPesa; stage; aim; chunk; remittance industry; offering speedier; alternatives
# BitPay; payment processing; merchants
# investors; portfolios; bitcoin alongside
# Coinbase; funding; group; investors; New York Stock Exchange; exchange; acceptance; services; industry; confidence
# Ripple Labs; approach; protocol; transmission; currency type; —; SMTP; money; payment
# end; it’s; agreements; Cross River Bank ( New Jersey ); CBW Bank ( Kansas ); Fidor Bank ( Germany )
# What’s; U.S.; regulatory regime
# New York’s Department; Financial; Services; BitLicense; path; trust; —
# attitude; FinCEN
# California; ban”; New York’s; footsteps; ( albeit
# spring; Federal Election Committee; donations; bitcoin
# response; currency industry; consumers; Laundering ( AML ); Know Your Customer ( KYC ); laws
# legislation; unwieldy; pastiche; it’s; picture
# investors; clients; business; partners; assurance; currency; companies
# horizon; applications; blockchain; developments; promising future
# applications; bitcoin’s; technology
# “coin”; asset; content; specifications; applications; range
# Companies; Filament; IBM; example; ledgers; devices; service; needs; information; owners; vendors; household
# Factom; Maidsafe; Storj; blockchain; data; protection; data; loss; theft
# range; use; cases; benefits; automobiles; equipment; repair; needs; schedule maintenance; machines; levels; secure
# currency; protocols; services; industry
# Remittance; payments; exchange; services; instruments; debt; instruments; depend; mortgages; reserve; services’ lifeblood
# projects; Ethereum; Ripple’s Codius; promise; regard
# developments; range; possibilities; libraries; decentralize; apps; ); smart; contracts; smart
# getting; currency world
# hand; older; industries
# IBM; contribution; ADEPT; protocol; MasterCard; options; direction; inclusion; currency
# Banks; telcos; home; electronics companies; companies; auto; manufacturers
# something; blockchain; technologies; companies; landscapes; order
# currency community; relationships
# blockchain; currency; worlds; turn; understanding; deep; inefficiencies; sectors
#
# refrain; services professionals; exceptions; developers; number; processes; e.g.; credit; cards; Federal Reserve; interest; rates; derivatives; equities; reserve banking
# That’s; complexity; innovations; hope
# reason; currency community; relationships; knowledge gap; invent; products
#
# chapters; bitcoin
# story; coders; investors; engineers; bankers
#
#
# Cropped; image; article; category; pages; Hiroyuki Takeda; Flickr; Creative Commons
#
# Four short links: 14 April 2015
# -------------------------------
# Pycon; Debt; The Monster; Closet ( YouTube ); excellent talk
#
# A/A Testing; In; A/A; test; test; same; options; “variants”
# That’s; there’s; difference
# “results.” (; Nelson Minar ) NSA Declares War; Computing ( BoingBoing ); NSA; director; Michael S Rogers; agency; front; doors; cryptography; USA; one; secrets; charge; software
# John; Neumann Documentary ( YouTube ); American Mathematical Association; father; computing; father
#
#
# Four short links: 13 April 2015
# -------------------------------
# Great Reversal; Demand; Skill; Cognitive Tasks ( PDF ); The; difference; models; change; modelling; fruits; employment; stock
# slight change; causes; change; boom; bust cycle; investment
# model; selection process; individuals; sort; occupations
# selection process; mechanism; reduction; demand; tasks; workers; loss; employment
# model; structure; observations; explanation
# provinces; state; province; lists
# Cultural Analytics; use; visualization; methods; analysis
#
# Code; Just; Symptom; The; engineering culture; cake; dysfunction; everyone; chain; task
# games; Simon; Telephone
# engineers; flashbacks
# Trigger; warning; descriptions; immature software
#
# 5 reasons why Python is a popular teaching language
# ---------------------------------------------------
# Download; copy; Python
# Editor; note; excerpt; Python; Education; report
# question; features; Python; language
# learning; Python; reading
#
# chapter; eyes; Python (; choice
# Code; readability; list; piece; paper; something; Shopping Fix; broken gutter; Mow; lawn; list
# to-do list; bit; something; Shopping; Eggs Bacon Tomatoes Fix; broken gutter; Borrow; ladder; door; Find; hammer; nails; Return
# Mow; lawn; Check; lawn; pond; frogs; Check; mower fuel level; tasks; sub-tasks; underneath
#
#
# manner; Python; tasks; Python
# example; code; function; say_hello; user; name; mdsh; prints; greeting; def; say_hello ( ); name; input
# print; name; code; action; user input
# Nicholas Hello; Nicholas [; caption; attachment_75689; align=; alignleft; width=; Download
# [ /caption; Notice; lines; code; say_hello; function; to-do
# Furthermore; instruction; code
# code; lines; code relate; way
# computer; languages; symbols; indentation
# example; languages; Java; JavaScript; C; use; semicolons
#
# students; language; need; dyslexia; indentation; something; people; world; understand; matter
# lack; symbols; code; lot easier; Python
# indentation; rules; code; students
# Compared; languages; Python’s
# example; code; Perl; programming language; words; text document
#
# (; Perl’s; defense; programming language; set; aims; objectives
# That’s; point; try; person; James Joyce’s Ulysses; English-language; novels
# ); Python; code
# Anything; lowers; effort; engage; programming; thing; context
# simplicity; simple core; concepts; knowledge; Python
# use; remember
# Furthermore; Python; programming language; thing; programmer; attempt
# It’s; sense; concepts; understood
# Consider; examples; languages; list; things; constructs; arrays; arraylists; vectors
# Python; something
# Here’s; to-do list; Python; todo_list; 'Fix; broken gutter; 'Mow; lawn; ]; code; list; values; strings; characters; words; tasks; to-do list; object; todo_list (; list
# languages; data dictionary; values; store; use; constructs; hashtables; arrays
#
# Here’s; data dictionary; selection; random capital; cities; capital_cities; 'Germany; 'Athens; 'Russia; Kingdom; } I’ve
# capital city; country; county’s; name; brackets; object; capital_cities; capital_cities; programming; languages; data structures; work; Python’s; lists; dictionaries; thing; call; constructs; “dictionaries”; languages; constructs; Python (
# Python’s; things; data structures; core part; language
# usefulness; simplicity; clarity; case; barriers
#
# example; sum; empty dictionary; empty list; something; that’s; — evidence; misunderstood; Python; Traceback; call; ); File; stdin; line; <; module; TypeError; operand type; s; +; use; “+” operand; sum
#
#
# idea; faulty code; error; uncertain; results; answer
# Here’s; JavaScript; language; equivalent; data structures; JavaScript; parlance; object; array; course
# Guess; happens; sum; empty array; object; JavaScript (
# >; object; Object ]
# (; caveat; JavaScript; having; set; aims; objectives
# ); Learning; nature; mistakes
#
# learning; program; language; JavaScript (; appears; guess; complain; error; sorts
# you’ll; mistaken view; programming world; rules; JavaScript; [ ] + { }; object; Object ]; difficult
# Python’s; simplicity; obviousness; encourages learners; developers
# code; bugs; bugs; misunderstanding
# state; ideas; code
# example; consider
# Players; world; locations; descriptions; exits
#
# program; comments; data dictionary
# block; code; behavior
# hunch; programmer
#
# world; data structure
#
# location; description; exits
#
# code; end; creates; game; loop; causes; turns; place
# turn; displays; user; location; exits; user; responds
# world; 'description
# 'exits; }; }; 'description
# 'exits; }; }; 'courtyard; 'description
# 'exits; }; 'description; gates
# 'exits; 'up; 'tower; }; }; 'description
# 'exits; }; }; }; Set; default
# place; Start; game; loop
# True; Get; location
# location; world; place; Print; location; description
# print; location; 'description; print; 'Exits; print; '.join (; location; 'exits; ]; .keys; Get
#
# .strip; (; Parse; user input; direction
# break; Break; game loop
# direction; location; 'exits; ]; Set; place
# place; location; 'exits; ]; direction; else
#
# “game”; user input; looks; something; python
#
#
#
# south; gates
#
#
#
#
#
# Furthermore; point; view; simple adventure game; sorts; ways; learners; objects; world; puzzles
# fact; opportunities; work
# game; form; fiction; English; department; students
# Open; extensibility; Despite; simplicity; core language; programmers; modules; code
# library module; recipe book; instructions
# programmers; scratch; reinvent; wheel; time
# programming; languages; mechanisms; libraries; code; Python; having; library; core language; thriving ecosystem
# example; task
# requests; module; Web; pages; Python; import; requests; response; ( 'http; True > > > response.text [ :42 ]; <; doctype html; <; lt; IE; html; code; Python; requests; HTML; Python’s; home page; checks; response; success; displays; characters; HTML
# ); modules
# modules; libraries; application; frameworks; tasks; types
# example; Django; application framework; writing; Web; applications; Mozilla; The Guardian; National Geographic; NASA; Instagram
# Django; tasks; modelling; data; database; templates; Web; pages; security; scalability
# care; Django; developers; task; websites
# languages; code; libraries; application; frameworks; Python’s; strength
# SciPy; NumPy; scientists; mathematicians; NLTK (; Natural Language Tool Kit ); linguists; text; Pandas; statisticians; OpenStack; control; computing
#
# language; real-world use; benefit; learners; skill; programming language
# aspect; Python
# Anyone; part; language; submitting bug; reports; patches; core; developers
# process; features; language
# way; language; view; community; uses; opportunity; community
# process; detail
# Cross-platform runability; Python; language; Microsoft Windows; Mac OS X; Linux; systems
# It’s; Python; service; websites
# context; Python; works; computers
# Students; computers; home; matter; make
# Furthermore; Python; service; excellent solution; problem; school system; administrators; teachers; anything; Microsoft Office; school
# Users; point; browser; Python; development environment
# Python; devices
# microcontrollers; chips; devices; appliances; controls; toys
# MicroPython; project; version; Python; devices; circuit board; svelte version; Python; caption; attachment_75686; align=; aligncenter; width=; MicroPython; board; size
# [ /caption; operating system; basis; sorts; fun
# Add-ons; board include; LCD; display screen; speaker; microphone
# task; robot
# BBC; MicroBit; project; device
# devices; UK; start; year
#
# MicroBit; clothing; couple; buttons; LED; matrix; text
# Raspberry Pi; Micro Python; board; ability; devices; I/O
# Python; languages; programming
# [ caption id=; attachment_75687; align=; aligncenter; width=; prototype; MicroBit; device
# [ /caption; advantage
# learning; Python; student; access; sorts; fun; platforms; tools
# Python; platforms; code; device; use; code; hardware; constraints
# Humanity; feature; language; Python’s; community; history; philosophy; code
# Monty Python; reference; website; hosts; Python; modules; Cheese Shop; sketch; shop; cheese; sense; fun; instance; “the PyPy project”; high-performance version; Python; Python ); apparent; eccentricities; Python; appearance
# It’s; humans; humans; abstract tool
# Python’s; community
# community; developers; teachers; students
# Python; community; secret weapon
#
# In design, what we really need is critical thinking
# ---------------------------------------------------
# Download; copy; Designing; Internet; Things; collection; chapters; Design
# post; excerpt; Discussing Design; Adam Connor; Aaron Irizarry; books
# ways; design; discussions; team member; feedback; something
# someone; desk; break; something
# part; milestone; date; timeline
# It’s; time
#
#
# time; la; love; feedback
# [ caption id=; attachment_74387; align=; alignright; width=; Download
# [ /caption; issue; term “feedback”; lies
# Feedback; reaction
# Designers; feedback; feedback; loops; time
# user; system; product; interacts; way; clicking; button; system; changes
# loading bar; data; elements; interface move
# reaction; system
#
# Feedback; reaction; result
# interactions; conversations; projects; nothing
#
# Reactions; bit; someone; cases
# discuss; Chapter; reaction doesn’t; allowing; creations
# reaction; built; biases; preferences; doing; reacting; cases; it’s; developer; designer; stakeholder; audience
# line; design; communities; user.” It’s; mind; discussing; things; creating; be
# problem; feedback; times; describing
#
# list; instructions
# Sometime; comments
# feedback; use; aspects; design
# kinds; feedback; Aaron; experiences; teams; characteristics; forms; feedback; level; usefulness
# kinds; feedback; conversations; teams; ability; feedback
# Reaction; Good
#
#
#
#
# Feedback; type; driven; own; expectations; desires
#
# kind; feedback; individual’s; understanding; understanding
# case; reaction; regard; what’s; situation; feedback
# Examples; kind; feedback
#
# issue; kind; feedback; tells; reaction
# kinds; reactions; product
# It’s; try; something potential; customers
# people; feedback
# Are; way; potential
# reaction tell; anything; design; decisions; made
# Direction; radio; buttons; drop; feedback; instruction
#
# form; feedback; providing; ways; creation; line; expectations
# examples; kind; feedback
# giving; feedback; vision
# solution; mind
# cases; suggestion; bit; thinking
# issue; feedback; feedback; explanation; nothing; effectiveness; decisions; meeting
# person; design; list; approval; approval; design
# situations; explanation; suggestion; begin; impetus; issue
# design; addressing
# type; feedback; leads; part; design process
# It’s; direction; idea; point; it’s
# talk; problem; impact
# talk; forms; feedback
# forms; terms; usefulness
# thinking; Critical; thinking; process; statement
# designing something; doing; set
# feedback; creations; method
# looking; form; analysis
#
# Critique; form; feedback; objective; users; impact; bank balance; purchase; balance; bottom; screen; size; numbers
# It’s; form; feedback; understanding; impact; design
# Critique isn’t; instant reaction; something; creation
# Critique; form; analysis; uses; creation; outcomes; pertinent
# outcomes; number; types
# utility; example; someone; ability
# metrics; measurement; number; conversions; call
# —; example; someone feel
# project; services; company; goals; site’s; design; visitors; time; articles; average number; articles; pieces; user
# goal; completion rate; contact form
# objectives; team; conversations; aspects; design; ideas
# Good; critique; details; aspect; idea; design decision
# aspect; decision; objective
# aspect; decision work; support; objective
# talk; Chapter; role; objectives; design; projects; setting; foundation; conversations; sense; differs; basis
# makes; difference
# semantics; it’s; word “feedback”; people; idea; creation; hell; we’ll
# see; chapters; what’s; difference; understanding; inform; people
# Cropped; image; article; category; pages; Patrick Hoesly; Flickr; Creative Commons
# post; part; investigation; Experience Design
#
# Four short links: 10 April 2015
# -------------------------------
# Maximum Clique; Large; Massive Real Graphs; explanation
# Robots; Prostheses; Human Touch; team; engineer; Veronica J. Santos; language; touch; computer
# researchers; touch; sensors; interact; objects; shapes
# array; instrumentation; Santos’; team; interaction; data
# data; formula; algorithm; computer; ability; patterns; items; library; experiences
# research; team develop artificial; intelligence; robots; prostheses; touch.”; boltons; things; Python
# Everything; Wish We 'd Known About Building Data; Products; ( DJ Patil; RusJan Belkin ); Data; messy; data; %
# words; data
# [; data
#
# company; problem; exception; data; quality; data; data; tracking; data; tracking data.”; problem; ton; time; energy; data
# monitor; alert; monitor
# data; quality; bugs
# be; deploy; data; quality
#
# Cross-pollinating Web communities
# ---------------------------------
# Web; projects; integration; projects; skills; number
# Lousy; interfaces; code; systems; resource
# “Content”; lurks; guises; support; writers; illustrators; video; specialists; game
# Marketers; businesses; Web; influence; conversations; design
# programmer; work
#
# Web; development; models
# websites; applications demands; collaboration; content; creators; designers
#
# projects; specialization; people; aspects; disciplines; networking; databases; systems
# ways; recipe; fragmentation; days
# communities; priorities
# Battles; resources; axes
# time; environments; resources; scarce; perspectives
# intersection; spaces; time; times; combinations
# possibilities; design; values; programming; contexts; example; keeps; traction
# term; Ted Nelson; efforts; computing; disciplines; '90s; variety; hypertext; multimedia; projects
#
# Hypermedia; charge
# ideas; work; exchange; exploration work; computers; terms; experience
# Web; developers; approaches; ivory tower; academia; Web; absorbing; lessons
# Roy Fielding; UC Irvine; dissertation; Architectural Styles; Design; Software Architectures; chapter
# course; Fielding; Apache HTTP Server; project; participant; software; standards processes; lot; people; REST
# crossovers; similarities
# software; architects; experience; designers; war; stories; meal; finding; challenges; interaction
# roles; groups; people; priorities; core; values
# structures; surface
# websites; applications demands; collaboration; content; creators; designers
#
# Git; epitome; programmer; tool; Linus Torvalds; weekend; months; completion; source code
#
#
#
#
#
#
# git; story; fits; needs; kinds; Web
# GitHub; git; Web; features; today; git
# similarities; collaborations; differences; collisions
#
# barriers; way; people; barriers; something
# Accessibility; folks; specialists; Web; architecture; details; browsers
# accessibility; specialists; call; practice
# tools; details; developers; work; front end; understanding; interaction
# accessibility; folks; consultants
# filter; Web; users; ask
# filter; collision; group; programmers; browsers
# days; Web; browsers; lot
# time; Netscape; source code base; Mozilla; Web
# People; Web; people; (; vice versa
# Today; people; Web; technologies; programmer; eye
# days; programmers
# course; groups; others; World Wide Web Consortium ( W3C ); kinds; voices; membership
# group; Web; cross-pollination; flow
# people; Web; stop; creating content
#
# constant flow; ideas; fields
# run; openness; keeps; Web
# Have; stories; success; failure
# Let; comments; Twitter ( @
# Photo; Berit Watkin
#
# post; part; exploration; communities; Web
#
# Open source won, so what&#8217;s next?
# --------------------------------------
# Twenty; years; source
#
# Today; Iron Throne
# Software; engineers; source; frameworks; languages; tools
# program; OSCON; program; chairs; source
# source; won; let; make
# Open; source; changes; software; spirit; founding community
# Pieces; puzzle; Languages; libraries; frameworks; Open; source; languages; Java; Python; Ruby; benefit; communities; problems; efficacy; optimization
# New; libraries; frameworks; augment; source; languages; software; engineers tools
# languages; libraries; frameworks; tools
# OSCON; tracks
# time; software; engineers
# days; JavaScript; frameworks; languages; database; choices; architectures; types
#
# year; tracks; software engineer
# Protect; Identity; privacy; security; facets; age; track
# Scale; From; compilation; interpreter time; DOM; manipulation; browser responsiveness; network latency; scale; performance
# Mobility; mobile game plan; wearables
# Collaboration; Making; work; communication; collaboration
# ways; generation; tools
#
# ideas; overcome impostor syndrome; work
# Architecture; Software; architecture; multidisciplinary subject; roles; responsibilities; position; success
# Design; success; learn; design; practices; beginning; project
# Data; data; influence; business world; present
# Foundations; foundation; thinking; problem; programming; practices
# Solve; Harness; power; math; secure
# weeks; posts
# software community; post; Software; engineers; organizations; source code; source culture; speed
# year; company culture; Cultivate; event
# values; practices; organizations; agility; changes; products
# teams; organization; leadership; skills; success; future; processes; work
# OSCON; OSCON; touches; aspects
#
# needs; community
# approach; event
# OSCON; time; conference; times; part
#
# Learn; OSCON

# %% [markdown]
# ## Example 10. Visualizing interactions between entities with HTML output

# %%
import os
import json
import nltk
from IPython.display import IFrame
from IPython.core.display import display

BLOG_DATA = "resources/ch05-webpages/feed.json"

HTML_TEMPLATE = """<html>
    <head>
        <title>%s</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>%s</body>
</html>"""

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:

    post.update(extract_interactions(post['content']))

    # Display output as markup with entities presented in bold text

    post['markup'] = []

    for sentence_idx in range(len(post['sentences'])):

        s = post['sentences'][sentence_idx]
        for (term, _) in post['entity_interactions'][sentence_idx]:
            s = s.replace(term, '<strong>%s</strong>' % (term, ))

        post['markup'] += [s] 
            
    filename = post['title'].replace("?", "") + '.entity_interactions.html'
    f = open(os.path.join('resources', 'ch05-webpages', filename), 'w')
    html = HTML_TEMPLATE % (post['title'] + ' Interactions', 
                            ' '.join(post['markup']),)
    f.write(html.encode('utf-8'))
    f.close()

    print "Data written to", f.name
    
    # Display any of these files with an inline frame. This displays the
    # last file processed by using the last value of f.name...
    
    print "Displaying %s:" % f.name
    display(IFrame('files/%s' % f.name, '100%', '600px'))

# %%
from bsddb import db

webDB = db.DB()
webDB.open("website.db", None, db.DB_HASH, db.DB_DIRTY_READ)

# get database cursor and print out database content
cursor = webDB.cursor()
rec = cursor.first()
while rec:
        print rec
        rec = cursor.next()
webDB.close()
# Out:
# ---------------------------------------------------------------------------
# DBNoSuchFileError                         Traceback (most recent call last)
# <ipython-input-31-0396d7e498b2> in <module>()
#       2
#       3 webDB = db.DB()
# ----> 4 webDB.open("website.db", None, db.DB_HASH, db.DB_DIRTY_READ)
#       5
#       6 # get database cursor and print out database content
#
# DBNoSuchFileError: (2, 'No such file or directory')

# %%
from bsddb import db

queueDB = db.DB()
queueDB.open("duplcheck.db", None, db.DB_HASH, db.DB_DIRTY_READ)

# get database cursor and print out database content
cursor = queueDB.cursor()
rec = cursor.first()
while rec:
        print rec
        rec = cursor.next()
queueDB.close()
# Out:
# ('http://www.glassdoor.com/Reviews/Merrill-Lynch-Reviews-E440.htm', '')

# %%
from crawler.crawler import Crawler

mycrawler = Crawler()
html = 'http://www.glassdoor.com/Reviews/Merrill-Lynch-Reviews-E440_p1.htm'
seeds = [html] # list of url
mycrawler.add_seeds(seeds)
rules = {'http://www.glassdoor.com/Reviews/Merrill-Lynch-Reviews-E440_p1.htm':[ '^(http://www.glassdoor.com/Reviews/Merrill-Lynch-Reviews-E440_p)([0-9])(.htm)$' ]}
#rules = {'http://www.glassdoor.com/Reviews/Merrill-Lynch-Reviews-E440.htm':[ '^(http://.+www.glassdoor.com/Reviews/Merrill-Lynch-Reviews-[a-zA-Z0-9_].htm)(.+)$' ]}
#your crawling rules: a dictionary type, 
#key is the regular expressions for url, 
#value is the list of regular expressions for urls which you want to follow from the url in key.
mycrawler.add_rules(rules)
mycrawler.start() # start crawling
# Out:
# http://www.glassdoor.com/Reviews/Merrill-Lynch-Reviews-E440_p1.htm
# sleep
#  0 of 3
# sleep
#  1 of 3
# sleep
#  2 of 3
# None
# crawling task is done.
